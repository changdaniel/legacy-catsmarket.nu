# %%
import requests
import json
from pprint import pprint

dataarray = [];

# for i in range(10000,15000):
#     params = {'key': 'JC3v77yRGJzdrHNn', 
#               'term': 4730, 
#               'id': i}
#     response = requests.get('http://api.asg.northwestern.edu/courses/details/?key=YOUR_KEY', params=params)
#     data = json.loads(response.text)
    
#     if(data != []):
#         dataarray.append(data);

# %%
params = {'key': 'KKcuJjfKntwrfVQd', 'term': 4730, 'id' : 3}
response = requests.get('http://api.asg.northwestern.edu/courses/details/?key=YOUR_KEY', params=params)
json_data = json.loads(response.text)



for data in json_data:
    data = {'id' : data['id'],
            'title' : data['title'],
            'term' : data['term'],
            'school' : data['school'], 
            'catalog_num' : data['catalog_num'],
            'section' : data['section'],
            "class_num": data['class_num'],
            "course_id": data['course_id']
           }
    pprint(data)

# %%
params = {'key': 'JC3v77yRGJzdrHNn'}
response = requests.get('http://api.asg.northwestern.edu/schools/?key=YOUR_KEY', params=params)
schoolarray = json.loads(response.text)
len_schoolarray = len(schoolarray)

# %%
#params = {'key': 'JC3v77yRGJzdrHNn', 'term':4730}
#response = requests.get('http://api.asg.northwestern.edu/subjects/?key=YOUR_KEY', params=params)


for i in range(len_schoolarray):
    schoolsymbol = schoolarray[i].get('symbol')
    params = {'key': 'JC3v77yRGJzdrHNn', 
              'term':4760, 
              'school' : schoolsymbol}
    response = requests.get('http://api.asg.northwestern.edu/subjects/?key=YOUR_KEY', params=params)
    schoolarray[i]['subjects'] = json.loads(response.text)

pprint(schoolarray)
# Out:
# [{'name': 'Medill School of Journalism',
#   'subjects': [{'name': 'Integrated Marketing Communications', 'symbol': 'IMC'},
#                {'name': 'Journalism', 'symbol': 'JOUR'}],
#   'symbol': 'JOUR'},
#  {'name': 'J L Kellogg  School Management',
#   'subjects': [{'name': 'Financial Economics', 'symbol': 'KELLG_FE'},
#                {'name': 'Managerial Analytics', 'symbol': 'KELLG_MA'}],
#   'symbol': 'KGSM'},
#  {'name': 'School of Law',
#   'subjects': [{'name': 'Litigation and Arbitration', 'symbol': 'LITARB'}],
#   'symbol': 'LAW'},
#  {'name': 'McCormick School of Engineering and Applied Science',
#   'subjects': [{'name': 'Biomedical Engineering', 'symbol': 'BMD_ENG'},
#                {'name': 'Chemical Engineering', 'symbol': 'CHEM_ENG'},
#                {'name': 'Civil and Environmental Engineering',
#                 'symbol': 'CIV_ENV'},
#                {'name': 'Computer Engineering', 'symbol': 'COMP_ENG'},
#                {'name': 'Computer Science', 'symbol': 'COMP_SCI'},
#                {'name': 'Career Development', 'symbol': 'CRDV'},
#                {'name': 'Segal Design Institute', 'symbol': 'DSGN'},
#                {'name': 'Electrical Engineering', 'symbol': 'ELEC_ENG'},
#                {'name': 'Entrepreneurship & Innovation', 'symbol': 'ENTREP'},
#                {'name': 'Engineering Science & Applied Math',
#                 'symbol': 'ES_APPM'},
#                {'name': 'General Engineering', 'symbol': 'GEN_ENG'},
#                {'name': 'Industrial Engineering & Management Sciences',
#                 'symbol': 'IEMS'},
#                {'name': 'Information Technology', 'symbol': 'INF_TECH'},
#                {'name': 'Center for Leadership', 'symbol': 'LDRSHP'},
#                {'name': 'Materials Science & Engineering', 'symbol': 'MAT_SCI'},
#                {'name': 'Masters in Biotechnology Program',
#                 'symbol': 'MBIOTECH'},
#                {'name': 'Mechanical Engineering', 'symbol': 'MECH_ENG'},
#                {'name': 'Master of Engineering Management', 'symbol': 'MEM'},
#                {'name': 'Artificial Intelligence', 'symbol': 'MSAI'},
#                {'name': 'Master of Science in Analytics', 'symbol': 'MSIA'},
#                {'name': 'Northwestern Institute for Complex Systems',
#                 'symbol': 'NICO'},
#                {'name': 'Personal Development', 'symbol': 'PRDV'},
#                {'name': 'Project Management', 'symbol': 'PROJ_MGT'},
#                {'name': 'Predictive Science and Engineering',
#                 'symbol': 'PSED'}],
#   'symbol': 'MEAS'},
#  {'name': 'Bienen School of Music',
#   'subjects': [{'name': 'Conducting', 'symbol': 'CONDUCT'},
#                {'name': 'General Music', 'symbol': 'GEN_MUS'},
#                {'name': 'Jazz Studies', 'symbol': 'JAZZ_ST'},
#                {'name': 'Music Composition', 'symbol': 'MUS_COMP'},
#                {'name': 'Music', 'symbol': 'MUSIC'},
#                {'name': 'Music Education', 'symbol': 'MUSIC_ED'},
#                {'name': 'Musicology', 'symbol': 'MUSICOL'},
#                {'name': 'Music Technology', 'symbol': 'MUS_TECH'},
#                {'name': 'Music Theory', 'symbol': 'MUS_THRY'},
#                {'name': 'Piano', 'symbol': 'PIANO'},
#                {'name': 'String Instruments', 'symbol': 'STRINGS'},
#                {'name': 'Voice & Opera', 'symbol': 'VOICE'},
#                {'name': 'Wind & Percussion', 'symbol': 'WIND_PER'}],
#   'symbol': 'MUSIC'},
#  {'name': 'Non-Degree Schools',
#   'subjects': [{'name': 'Naval Science', 'symbol': 'NAV_SCI'}],
#   'symbol': 'NDGR'},
#  {'name': 'School of Educ & Social Policy',
#   'subjects': [{'name': 'Human Development & Psychological Services',
#                 'symbol': 'HDPS'},
#                {'name': 'Human Development & Social Policy', 'symbol': 'HDSP'},
#                {'name': 'Learning & Organizational Change', 'symbol': 'LOC'},
#                {'name': 'Learning Sciences', 'symbol': 'LRN_SCI'},
#                {'name': 'MS in Education & Social Policy', 'symbol': 'MS_ED'},
#                {'name': 'MS in Higher Education Administration and Policy',
#                 'symbol': 'MS_HE'},
#                {'name': 'Learning & Organizational Change', 'symbol': 'MS_LOC'},
#                {'name': 'School of Education & Social Policy Core',
#                 'symbol': 'SESP'},
#                {'name': 'Social Policy', 'symbol': 'SOC_POL'},
#                {'name': 'Teacher Education', 'symbol': 'TEACH_ED'}],
#   'symbol': 'SESP'},
#  {'name': 'School of Communication',
#   'subjects': [{'name': 'Communication Related Courses', 'symbol': 'CMN'},
#                {'name': 'Communication Studies', 'symbol': 'COMM_ST'},
#                {'name': 'Communication Sciences and Disorders',
#                 'symbol': 'CSD'},
#                {'name': 'Dance', 'symbol': 'DANCE'},
#                {'name': 'Health Communication', 'symbol': 'HLTH_COM'},
#                {'name': 'Master of Science in Communication', 'symbol': 'MSC'},
#                {'name': 'MS Leadership for Creative Enterprises',
#                 'symbol': 'MSLCE'},
#                {'name': 'Media, Technology & Society', 'symbol': 'MTS'},
#                {'name': 'Performance Studies', 'symbol': 'PERF_ST'},
#                {'name': 'Radio/Television/Film', 'symbol': 'RTVF'},
#                {'name': 'Sound Arts and Industries', 'symbol': 'SAI'},
#                {'name': 'Theatre', 'symbol': 'THEATRE'}],
#   'symbol': 'SPCH'},
#  {'name': 'The Graduate School',
#   'subjects': [{'name': 'Applied Physics', 'symbol': 'APP_PHYS'},
#                {'name': 'Comparative & Historical Social Science',
#                 'symbol': 'CHSS'},
#                {'name': 'Clinical Psychology', 'symbol': 'CLIN_PSY'},
#                {'name': 'Chicago Metropolitan Exchange Program',
#                 'symbol': 'CME'},
#                {'name': 'Data Science', 'symbol': 'DATA_SCI'},
#                {'name': 'Epidemiology & Biostatistics', 'symbol': 'EPI_BIO'},
#                {'name': 'Genetic Counseling', 'symbol': 'GENET_CN'},
#                {'name': 'Healthcare Quality and Patient  Safety',
#                 'symbol': 'HQS'},
#                {'name': 'Health Sciences Integrated Program', 'symbol': 'HSIP'},
#                {'name': 'Integrated Life Sciences', 'symbol': 'IGP'},
#                {'name': 'Master of Science in Clinical Investigation',
#                 'symbol': 'MSCI'},
#                {'name': 'Plant Biology & Conservation', 'symbol': 'PBC'},
#                {'name': 'Public Health', 'symbol': 'PUB_HLTH'},
#                {'name': 'Reproductive Science and Medicine',
#                 'symbol': 'REPR_SCI'},
#                {'name': 'TGS General Registrations', 'symbol': 'TGS'}],
#   'symbol': 'TGS'},
#  {'name': 'Continuing Education', 'subjects': [], 'symbol': 'UC'},
#  {'name': 'Weinberg College of Arts and Sciences',
#   'subjects': [{'name': 'African American Studies', 'symbol': 'AF_AM_ST'},
#                {'name': 'African Studies', 'symbol': 'AFST'},
#                {'name': 'American Studies', 'symbol': 'AMER_ST'},
#                {'name': 'Anthropology', 'symbol': 'ANTHRO'},
#                {'name': 'Arabic', 'symbol': 'ARABIC'},
#                {'name': 'Art Theory & Practice', 'symbol': 'ART'},
#                {'name': 'Art History', 'symbol': 'ART_HIST'},
#                {'name': 'Asian American Studies', 'symbol': 'ASIAN_AM'},
#                {'name': 'Asian Languages and Cultures', 'symbol': 'ASIAN_LC'},
#                {'name': 'Astronomy', 'symbol': 'ASTRON'},
#                {'name': 'Biological Sciences', 'symbol': 'BIOL_SCI'},
#                {'name': 'Business Institutions', 'symbol': 'BUS_INST'},
#                {'name': 'Chicago Field Studies', 'symbol': 'CFS'},
#                {'name': 'Chemistry', 'symbol': 'CHEM'},
#                {'name': 'Chinese', 'symbol': 'CHINESE'},
#                {'name': 'Classics - Readings in English', 'symbol': 'CLASSICS'},
#                {'name': 'Cognitive Science', 'symbol': 'COG_SCI'},
#                {'name': 'Comparative Literary Studies', 'symbol': 'COMP_LIT'},
#                {'name': 'Earth and Planetary Sciences', 'symbol': 'EARTH'},
#                {'name': 'Economics', 'symbol': 'ECON'},
#                {'name': 'English', 'symbol': 'ENGLISH'},
#                {'name': 'Environmental Policy & Culture', 'symbol': 'ENVR_POL'},
#                {'name': 'Environmental Science', 'symbol': 'ENVR_SCI'},
#                {'name': 'French', 'symbol': 'FRENCH'},
#                {'name': 'Global Avant-garde and Modernist Studies',
#                 'symbol': 'GAMS'},
#                {'name': 'Global Health', 'symbol': 'GBL_HLTH'},
#                {'name': 'Geography', 'symbol': 'GEOG'},
#                {'name': 'German', 'symbol': 'GERMAN'},
#                {'name': 'Gender Studies', 'symbol': 'GNDR_ST'},
#                {'name': 'Greek', 'symbol': 'GREEK'},
#                {'name': 'Hebrew', 'symbol': 'HEBREW'},
#                {'name': 'Hindi and Urdu', 'symbol': 'HIND_URD'},
#                {'name': 'History', 'symbol': 'HISTORY'},
#                {'name': 'Humanities', 'symbol': 'HUM'},
#                {'name': 'Interdisciplinary Biological Sciences Program',
#                 'symbol': 'IBIS'},
#                {'name': 'Integrated Science', 'symbol': 'INTG_SCI'},
#                {'name': 'International Studies', 'symbol': 'INTL_ST'},
#                {'name': 'Initiative for Sustainability & Energy at NU',
#                 'symbol': 'ISEN'},
#                {'name': 'Italian', 'symbol': 'ITALIAN'},
#                {'name': 'Japanese', 'symbol': 'JAPANESE'},
#                {'name': 'Jewish Studies', 'symbol': 'JWSH_ST'},
#                {'name': 'Korean', 'symbol': 'KOREAN'},
#                {'name': 'Latin', 'symbol': 'LATIN'},
#                {'name': 'Latina and Latino Studies', 'symbol': 'LATINO'},
#                {'name': 'Legal Studies', 'symbol': 'LEGAL_ST'},
#                {'name': 'Linguistics', 'symbol': 'LING'},
#                {'name': 'Mathematics', 'symbol': 'MATH'},
#                {'name': 'Middle East and North African Studies',
#                 'symbol': 'MENA'},
#                {'name': 'Math Methods in the Social Sciences',
#                 'symbol': 'MMSS'},
#                {'name': 'Neurobiology & Physiology', 'symbol': 'NEUROBIO'},
#                {'name': 'Neuroscience', 'symbol': 'NEUROSCI'},
#                {'name': 'Persian', 'symbol': 'PERSIAN'},
#                {'name': 'Philosophy', 'symbol': 'PHIL'},
#                {'name': 'Physics', 'symbol': 'PHYSICS'},
#                {'name': 'Political Science', 'symbol': 'POLI_SCI'},
#                {'name': 'Polish', 'symbol': 'POLISH'},
#                {'name': 'Portuguese', 'symbol': 'PORT'},
#                {'name': 'Psychology', 'symbol': 'PSYCH'},
#                {'name': 'Religious Studies', 'symbol': 'RELIGION'},
#                {'name': 'Russian', 'symbol': 'RUSSIAN'},
#                {'name': 'Slavic Languages & Literature', 'symbol': 'SLAVIC'},
#                {'name': 'Sociology', 'symbol': 'SOCIOL'},
#                {'name': 'Spanish', 'symbol': 'SPANISH'},
#                {'name': 'Spanish and Portuguese', 'symbol': 'SPANPORT'},
#                {'name': 'Statistics', 'symbol': 'STAT'},
#                {'name': 'Swahili', 'symbol': 'SWAHILI'},
#                {'name': 'Turkish', 'symbol': 'TURKISH'}],
#   'symbol': 'WCAS'}]

# %%
detailedschoolarray = schoolarray.copy()

# %%
for schoolindex in range(len_schoolarray):
    
    school = detailedschoolarray[schoolindex]
    subjectarray = school.get('subjects')
    len_subjectarray = len(subjectarray)
    
    for subjectindex in range(len_subjectarray):
        
        params = {'key': 'JC3v77yRGJzdrHNn', 
                  'term': 4760,
                  'subject' : subjectarray[subjectindex].get('symbol')}
        response = requests.get('http://api.asg.northwestern.edu/courses/details/?key=YOUR_KEY', params=params)
        coursesarray = json.loads(response.text)
        #
        detailedschoolarray[schoolindex]['subjects'][subjectindex]['courses'] = [] 
        for course in coursesarray:
            course = {'id' : course['id'],
                      'title' : course['title'],
                      'term' : course['term'],
                      'school' : course['school'], 
                      'catalog_num' : course['catalog_num'],
                      'section' : course['section'],
                      'class_num': course['class_num'],
                      'course_id': course['course_id'],
                      'subject': course['subject']}
            detailedschoolarray[schoolindex]['subjects'][subjectindex]['courses'].append(course)
            
            
#for full courses data, comment out evreything below the above comment symbol, and replace with

# %%
testarray = schoolarray[0]['subjects'][1]
params = {'key': 'JC3v77yRGJzdrHNn', 
          'term': 4760,
          'subject' : testarray.get('symbol')}
response = requests.get('http://api.asg.northwestern.edu/courses/details/?key=YOUR_KEY', params=params)
pprint(json.loads(response.text))
# Out:
# [{'attributes': None,
#   'catalog_num': '201-1',
#   'class_num': 16068,
#   'component': 'LEC',
#   'course_components': [],
#   'course_descriptions': [],
#   'course_id': 926,
#   'end_date': '2019-12-07',
#   'end_time': '14:20',
#   'id': 188160,
#   'instructor': {'address': None,
#                  'bio': None,
#                  'name': 'Caryn B Ward',
#                  'office_hours': None,
#                  'phone': None},
#   'meeting_days': 'MoWe',
#   'overview': 'This course builds a strong foundation for all Medill classes '
#               'to follow by introducing students to the essentials of accurate '
#               'journalism necessary for any platform or storytelling format. '
#               'This includes news judgment, news and information gathering '
#               '(including sourcing, discovering and covering different kinds '
#               'of news, interviewing techniques, practices of inclusion and '
#               'sensitivity); constructing stories (including leads, story '
#               'structure, using quotes, using data to tell a story, assessing '
#               'information); editing and presentation (grammar, punctuation, '
#               'AP style, voice, tone, clarity, brevity); avoiding libel and '
#               'other legal pitfalls; and visual literacy and presentation. '
#               'This course emphasizes the critical practices of ethical '
#               'journalism and deadline reporting and writing.',
#   'requirements': 'Enrollment Requirements: This section is currently closed '
#                   'to registration.  Please contact the department directly '
#                   'with any questions.',
#   'room': {'building_id': 60,
#            'building_name': 'Fisk Hall',
#            'id': 181,
#            'name': '206'},
#   'school': 'JOUR',
#   'seats': 14,
#   'section': '32',
#   'start_date': '2019-09-24',
#   'start_time': '13:00',
#   'subject': 'JOUR',
#   'term': '2019 Fall',
#   'title': 'Reporting & Writing',
#   'topic': None},
#  {'attributes': None,
#   'catalog_num': '201-1',
#   'class_num': 16174,
#   'component': 'LEC',
#   'course_components': [],
#   'course_descriptions': [],
#   'course_id': 926,
#   'end_date': '2019-12-07',
#   'end_time': '14:20',
#   'id': 188158,
#   'instructor': {'address': None,
#                  'bio': None,
#                  'name': 'Cynthia B Rodgers',
#                  'office_hours': None,
#                  'phone': None},
#   'meeting_days': 'MoWe',
#   'overview': 'This course builds a strong foundation for all Medill classes '
#               'to follow by introducing students to the essentials of accurate '
#               'journalism necessary for any platform or storytelling format. '
#               'This includes news judgment, news and information gathering '
#               '(including sourcing, discovering and covering different kinds '
#               'of news, interviewing techniques, practices of inclusion and '
#               'sensitivity); constructing stories (including leads, story '
#               'structure, using quotes, using data to tell a story, assessing '
#               'information); editing and presentation (grammar, punctuation, '
#               'AP style, voice, tone, clarity, brevity); avoiding libel and '
#               'other legal pitfalls; and visual literacy and presentation. '
#               'This course emphasizes the critical practices of ethical '
#               'journalism and deadline reporting and writing.',
#   'requirements': 'Enrollment Requirements: This section is currently closed '
#                   'to registration.  Please contact the department directly '
#                   'with any questions.',
#   'room': {'building_id': 60,
#            'building_name': 'Fisk Hall',
#            'id': 191,
#            'name': 'B11'},
#   'school': 'JOUR',
#   'seats': 14,
#   'section': '30',
#   'start_date': '2019-09-24',
#   'start_time': '13:00',
#   'subject': 'JOUR',
#   'term': '2019 Fall',
#   'title': 'Reporting & Writing',
#   'topic': None},
#  {'attributes': None,
#   'catalog_num': '201-1',
#   'class_num': 16168,
#   'component': 'LEC',
#   'course_components': [],
#   'course_descriptions': [],
#   'course_id': 926,
#   'end_date': '2019-12-07',
#   'end_time': '14:20',
#   'id': 188152,
#   'instructor': {'address': None,
#                  'bio': None,
#                  'name': 'Melissa K Isaacson',
#                  'office_hours': None,
#                  'phone': None},
#   'meeting_days': 'MoWe',
#   'overview': 'This course builds a strong foundation for all Medill classes '
#               'to follow by introducing students to the essentials of accurate '
#               'journalism necessary for any platform or storytelling format. '
#               'This includes news judgment, news and information gathering '
#               '(including sourcing, discovering and covering different kinds '
#               'of news, interviewing techniques, practices of inclusion and '
#               'sensitivity); constructing stories (including leads, story '
#               'structure, using quotes, using data to tell a story, assessing '
#               'information); editing and presentation (grammar, punctuation, '
#               'AP style, voice, tone, clarity, brevity); avoiding libel and '
#               'other legal pitfalls; and visual literacy and presentation. '
#               'This course emphasizes the critical practices of ethical '
#               'journalism and deadline reporting and writing.',
#   'requirements': 'Enrollment Requirements: This section is currently closed '
#                   'to registration.  Please contact the department directly '
#                   'with any questions.',
#   'room': None,
#   'school': 'JOUR',
#   'seats': 14,
#   'section': '24',
#   'start_date': '2019-09-24',
#   'start_time': '13:00',
#   'subject': 'JOUR',
#   'term': '2019 Fall',
#   'title': 'Reporting & Writing',
#   'topic': None},
#  {'attributes': None,
#   'catalog_num': '201-1',
#   'class_num': 16170,
#   'component': 'LEC',
#   'course_components': [],
#   'course_descriptions': [],
#   'course_id': 926,
#   'end_date': '2019-12-07',
#   'end_time': '14:20',
#   'id': 188154,
#   'instructor': {'address': None,
#                  'bio': None,
#                  'name': 'Michael Anthony Deas',
#                  'office_hours': None,
#                  'phone': None},
#   'meeting_days': 'MoWe',
#   'overview': 'This course builds a strong foundation for all Medill classes '
#               'to follow by introducing students to the essentials of accurate '
#               'journalism necessary for any platform or storytelling format. '
#               'This includes news judgment, news and information gathering '
#               '(including sourcing, discovering and covering different kinds '
#               'of news, interviewing techniques, practices of inclusion and '
#               'sensitivity); constructing stories (including leads, story '
#               'structure, using quotes, using data to tell a story, assessing '
#               'information); editing and presentation (grammar, punctuation, '
#               'AP style, voice, tone, clarity, brevity); avoiding libel and '
#               'other legal pitfalls; and visual literacy and presentation. '
#               'This course emphasizes the critical practices of ethical '
#               'journalism and deadline reporting and writing.',
#   'requirements': 'Enrollment Requirements: This section is currently closed '
#                   'to registration.  Please contact the department directly '
#                   'with any questions.',
#   'room': {'building_id': 60,
#            'building_name': 'Fisk Hall',
#            'id': 188,
#            'name': '309'},
#   'school': 'JOUR',
#   'seats': 14,
#   'section': '26',
#   'start_date': '2019-09-24',
#   'start_time': '13:00',
#   'subject': 'JOUR',
#   'term': '2019 Fall',
#   'title': 'Reporting & Writing',
#   'topic': None},
#  {'attributes': None,
#   'catalog_num': '201-1',
#   'class_num': 14555,
#   'component': 'LEC',
#   'course_components': [],
#   'course_descriptions': [],
#   'course_id': 926,
#   'end_date': '2019-12-07',
#   'end_time': '14:20',
#   'id': 188148,
#   'instructor': {'address': None,
#                  'bio': None,
#                  'name': 'Mei-Ling Hopgood Reel',
#                  'office_hours': None,
#                  'phone': None},
#   'meeting_days': 'MoWe',
#   'overview': 'This course builds a strong foundation for all Medill classes '
#               'to follow by introducing students to the essentials of accurate '
#               'journalism necessary for any platform or storytelling format. '
#               'This includes news judgment, news and information gathering '
#               '(including sourcing, discovering and covering different kinds '
#               'of news, interviewing techniques, practices of inclusion and '
#               'sensitivity); constructing stories (including leads, story '
#               'structure, using quotes, using data to tell a story, assessing '
#               'information); editing and presentation (grammar, punctuation, '
#               'AP style, voice, tone, clarity, brevity); avoiding libel and '
#               'other legal pitfalls; and visual literacy and presentation. '
#               'This course emphasizes the critical practices of ethical '
#               'journalism and deadline reporting and writing.',
#   'requirements': 'Enrollment Requirements: This section is currently closed '
#                   'to registration.  Please contact the department directly '
#                   'with any questions.',
#   'room': None,
#   'school': 'JOUR',
#   'seats': 14,
#   'section': '20',
#   'start_date': '2019-09-24',
#   'start_time': '13:00',
#   'subject': 'JOUR',
#   'term': '2019 Fall',
#   'title': 'Reporting & Writing',
#   'topic': None},
#  {'attributes': None,
#   'catalog_num': '201-1',
#   'class_num': 16066,
#   'component': 'LEC',
#   'course_components': [],
#   'course_descriptions': [],
#   'course_id': 926,
#   'end_date': '2019-12-07',
#   'end_time': '14:20',
#   'id': 188150,
#   'instructor': {'address': None,
#                  'bio': None,
#                  'name': 'Lawrence L Stuelpnagel',
#                  'office_hours': None,
#                  'phone': None},
#   'meeting_days': 'MoWe',
#   'overview': 'This course builds a strong foundation for all Medill classes '
#               'to follow by introducing students to the essentials of accurate '
#               'journalism necessary for any platform or storytelling format. '
#               'This includes news judgment, news and information gathering '
#               '(including sourcing, discovering and covering different kinds '
#               'of news, interviewing techniques, practices of inclusion and '
#               'sensitivity); constructing stories (including leads, story '
#               'structure, using quotes, using data to tell a story, assessing '
#               'information); editing and presentation (grammar, punctuation, '
#               'AP style, voice, tone, clarity, brevity); avoiding libel and '
#               'other legal pitfalls; and visual literacy and presentation. '
#               'This course emphasizes the critical practices of ethical '
#               'journalism and deadline reporting and writing.',
#   'requirements': 'Enrollment Requirements: This section is currently closed '
#                   'to registration.  Please contact the department directly '
#                   'with any questions.',
#   'room': None,
#   'school': 'JOUR',
#   'seats': 14,
#   'section': '22',
#   'start_date': '2019-09-24',
#   'start_time': '13:00',
#   'subject': 'JOUR',
#   'term': '2019 Fall',
#   'title': 'Reporting & Writing',
#   'topic': None},
#  {'attributes': None,
#   'catalog_num': '201-1',
#   'class_num': 16067,
#   'component': 'LEC',
#   'course_components': [],
#   'course_descriptions': [],
#   'course_id': 926,
#   'end_date': '2019-12-07',
#   'end_time': '14:20',
#   'id': 188151,
#   'instructor': {'address': None,
#                  'bio': None,
#                  'name': 'Desiree Hanford',
#                  'office_hours': None,
#                  'phone': None},
#   'meeting_days': 'MoWe',
#   'overview': 'This course builds a strong foundation for all Medill classes '
#               'to follow by introducing students to the essentials of accurate '
#               'journalism necessary for any platform or storytelling format. '
#               'This includes news judgment, news and information gathering '
#               '(including sourcing, discovering and covering different kinds '
#               'of news, interviewing techniques, practices of inclusion and '
#               'sensitivity); constructing stories (including leads, story '
#               'structure, using quotes, using data to tell a story, assessing '
#               'information); editing and presentation (grammar, punctuation, '
#               'AP style, voice, tone, clarity, brevity); avoiding libel and '
#               'other legal pitfalls; and visual literacy and presentation. '
#               'This course emphasizes the critical practices of ethical '
#               'journalism and deadline reporting and writing.',
#   'requirements': 'Enrollment Requirements: This section is currently closed '
#                   'to registration.  Please contact the department directly '
#                   'with any questions.',
#   'room': None,
#   'school': 'JOUR',
#   'seats': 14,
#   'section': '23',
#   'start_date': '2019-09-24',
#   'start_time': '13:00',
#   'subject': 'JOUR',
#   'term': '2019 Fall',
#   'title': 'Reporting & Writing',
#   'topic': None},
#  {'attributes': None,
#   'catalog_num': '201-1',
#   'class_num': 14556,
#   'component': 'LEC',
#   'course_components': [],
#   'course_descriptions': [],
#   'course_id': 926,
#   'end_date': '2019-12-07',
#   'end_time': '14:20',
#   'id': 188149,
#   'instructor': {'address': None,
#                  'bio': None,
#                  'name': 'Steven William Thrasher',
#                  'office_hours': None,
#                  'phone': None},
#   'meeting_days': 'MoWe',
#   'overview': 'This course builds a strong foundation for all Medill classes '
#               'to follow by introducing students to the essentials of accurate '
#               'journalism necessary for any platform or storytelling format. '
#               'This includes news judgment, news and information gathering '
#               '(including sourcing, discovering and covering different kinds '
#               'of news, interviewing techniques, practices of inclusion and '
#               'sensitivity); constructing stories (including leads, story '
#               'structure, using quotes, using data to tell a story, assessing '
#               'information); editing and presentation (grammar, punctuation, '
#               'AP style, voice, tone, clarity, brevity); avoiding libel and '
#               'other legal pitfalls; and visual literacy and presentation. '
#               'This course emphasizes the critical practices of ethical '
#               'journalism and deadline reporting and writing.',
#   'requirements': 'Enrollment Requirements: This section is currently closed '
#                   'to registration.  Please contact the department directly '
#                   'with any questions.',
#   'room': {'building_id': 60,
#            'building_name': 'Fisk Hall',
#            'id': 186,
#            'name': '307'},
#   'school': 'JOUR',
#   'seats': 14,
#   'section': '21',
#   'start_date': '2019-09-24',
#   'start_time': '13:00',
#   'subject': 'JOUR',
#   'term': '2019 Fall',
#   'title': 'Reporting & Writing',
#   'topic': None},
#  {'attributes': None,
#   'catalog_num': '201-1',
#   'class_num': 16169,
#   'component': 'LEC',
#   'course_components': [],
#   'course_descriptions': [],
#   'course_id': 926,
#   'end_date': '2019-12-07',
#   'end_time': '14:20',
#   'id': 188153,
#   'instructor': {'address': None,
#                  'bio': None,
#                  'name': 'Patti Lynne Wolter',
#                  'office_hours': None,
#                  'phone': None},
#   'meeting_days': 'MoWe',
#   'overview': 'This course builds a strong foundation for all Medill classes '
#               'to follow by introducing students to the essentials of accurate '
#               'journalism necessary for any platform or storytelling format. '
#               'This includes news judgment, news and information gathering '
#               '(including sourcing, discovering and covering different kinds '
#               'of news, interviewing techniques, practices of inclusion and '
#               'sensitivity); constructing stories (including leads, story '
#               'structure, using quotes, using data to tell a story, assessing '
#               'information); editing and presentation (grammar, punctuation, '
#               'AP style, voice, tone, clarity, brevity); avoiding libel and '
#               'other legal pitfalls; and visual literacy and presentation. '
#               'This course emphasizes the critical practices of ethical '
#               'journalism and deadline reporting and writing.',
#   'requirements': 'Enrollment Requirements: This section is currently closed '
#                   'to registration.  Please contact the department directly '
#                   'with any questions.',
#   'room': {'building_id': 80,
#            'building_name': 'Locy Hall',
#            'id': 367,
#            'name': '213'},
#   'school': 'JOUR',
#   'seats': 14,
#   'section': '25',
#   'start_date': '2019-09-24',
#   'start_time': '13:00',
#   'subject': 'JOUR',
#   'term': '2019 Fall',
#   'title': 'Reporting & Writing',
#   'topic': None},
#  {'attributes': None,
#   'catalog_num': '201-1',
#   'class_num': 16171,
#   'component': 'LEC',
#   'course_components': [],
#   'course_descriptions': [],
#   'course_id': 926,
#   'end_date': '2019-12-07',
#   'end_time': '14:20',
#   'id': 188155,
#   'instructor': {'address': None,
#                  'bio': None,
#                  'name': 'Richard Babcock',
#                  'office_hours': None,
#                  'phone': None},
#   'meeting_days': 'MoWe',
#   'overview': 'This course builds a strong foundation for all Medill classes '
#               'to follow by introducing students to the essentials of accurate '
#               'journalism necessary for any platform or storytelling format. '
#               'This includes news judgment, news and information gathering '
#               '(including sourcing, discovering and covering different kinds '
#               'of news, interviewing techniques, practices of inclusion and '
#               'sensitivity); constructing stories (including leads, story '
#               'structure, using quotes, using data to tell a story, assessing '
#               'information); editing and presentation (grammar, punctuation, '
#               'AP style, voice, tone, clarity, brevity); avoiding libel and '
#               'other legal pitfalls; and visual literacy and presentation. '
#               'This course emphasizes the critical practices of ethical '
#               'journalism and deadline reporting and writing.',
#   'requirements': 'Enrollment Requirements: This section is currently closed '
#                   'to registration.  Please contact the department directly '
#                   'with any questions.',
#   'room': {'building_id': 60,
#            'building_name': 'Fisk Hall',
#            'id': 187,
#            'name': '308'},
#   'school': 'JOUR',
#   'seats': 14,
#   'section': '27',
#   'start_date': '2019-09-24',
#   'start_time': '13:00',
#   'subject': 'JOUR',
#   'term': '2019 Fall',
#   'title': 'Reporting & Writing',
#   'topic': None},
#  {'attributes': None,
#   'catalog_num': '201-1',
#   'class_num': 16173,
#   'component': 'LEC',
#   'course_components': [],
#   'course_descriptions': [],
#   'course_id': 926,
#   'end_date': '2019-12-07',
#   'end_time': '14:20',
#   'id': 188157,
#   'instructor': {'address': None,
#                  'bio': None,
#                  'name': 'Ava Thompson Greenwell',
#                  'office_hours': None,
#                  'phone': None},
#   'meeting_days': 'MoWe',
#   'overview': 'This course builds a strong foundation for all Medill classes '
#               'to follow by introducing students to the essentials of accurate '
#               'journalism necessary for any platform or storytelling format. '
#               'This includes news judgment, news and information gathering '
#               '(including sourcing, discovering and covering different kinds '
#               'of news, interviewing techniques, practices of inclusion and '
#               'sensitivity); constructing stories (including leads, story '
#               'structure, using quotes, using data to tell a story, assessing '
#               'information); editing and presentation (grammar, punctuation, '
#               'AP style, voice, tone, clarity, brevity); avoiding libel and '
#               'other legal pitfalls; and visual literacy and presentation. '
#               'This course emphasizes the critical practices of ethical '
#               'journalism and deadline reporting and writing.',
#   'requirements': 'Enrollment Requirements: This section is currently closed '
#                   'to registration.  Please contact the department directly '
#                   'with any questions.',
#   'room': None,
#   'school': 'JOUR',
#   'seats': 14,
#   'section': '29',
#   'start_date': '2019-09-24',
#   'start_time': '13:00',
#   'subject': 'JOUR',
#   'term': '2019 Fall',
#   'title': 'Reporting & Writing',
#   'topic': None},
#  {'attributes': None,
#   'catalog_num': '201-1',
#   'class_num': 16175,
#   'component': 'LEC',
#   'course_components': [],
#   'course_descriptions': [],
#   'course_id': 926,
#   'end_date': '2019-12-07',
#   'end_time': '14:20',
#   'id': 188159,
#   'instructor': {'address': None,
#                  'bio': None,
#                  'name': 'Patti Lynne Wolter',
#                  'office_hours': None,
#                  'phone': None},
#   'meeting_days': 'MoWe',
#   'overview': 'This course builds a strong foundation for all Medill classes '
#               'to follow by introducing students to the essentials of accurate '
#               'journalism necessary for any platform or storytelling format. '
#               'This includes news judgment, news and information gathering '
#               '(including sourcing, discovering and covering different kinds '
#               'of news, interviewing techniques, practices of inclusion and '
#               'sensitivity); constructing stories (including leads, story '
#               'structure, using quotes, using data to tell a story, assessing '
#               'information); editing and presentation (grammar, punctuation, '
#               'AP style, voice, tone, clarity, brevity); avoiding libel and '
#               'other legal pitfalls; and visual literacy and presentation. '
#               'This course emphasizes the critical practices of ethical '
#               'journalism and deadline reporting and writing.',
#   'requirements': 'Enrollment Requirements: This section is currently closed '
#                   'to registration.  Please contact the department directly '
#                   'with any questions.',
#   'room': {'building_id': 60,
#            'building_name': 'Fisk Hall',
#            'id': 193,
#            'name': 'B4'},
#   'school': 'JOUR',
#   'seats': 14,
#   'section': '31',
#   'start_date': '2019-09-24',
#   'start_time': '13:00',
#   'subject': 'JOUR',
#   'term': '2019 Fall',
#   'title': 'Reporting & Writing',
#   'topic': None},
#  {'attributes': None,
#   'catalog_num': '201-1',
#   'class_num': 16172,
#   'component': 'LEC',
#   'course_components': [],
#   'course_descriptions': [],
#   'course_id': 926,
#   'end_date': '2019-12-07',
#   'end_time': '14:20',
#   'id': 188156,
#   'instructor': {'address': None,
#                  'bio': None,
#                  'name': 'Stephan W Garnett',
#                  'office_hours': None,
#                  'phone': None},
#   'meeting_days': 'MoWe',
#   'overview': 'This course builds a strong foundation for all Medill classes '
#               'to follow by introducing students to the essentials of accurate '
#               'journalism necessary for any platform or storytelling format. '
#               'This includes news judgment, news and information gathering '
#               '(including sourcing, discovering and covering different kinds '
#               'of news, interviewing techniques, practices of inclusion and '
#               'sensitivity); constructing stories (including leads, story '
#               'structure, using quotes, using data to tell a story, assessing '
#               'information); editing and presentation (grammar, punctuation, '
#               'AP style, voice, tone, clarity, brevity); avoiding libel and '
#               'other legal pitfalls; and visual literacy and presentation. '
#               'This course emphasizes the critical practices of ethical '
#               'journalism and deadline reporting and writing.',
#   'requirements': 'Enrollment Requirements: This section is currently closed '
#                   'to registration.  Please contact the department directly '
#                   'with any questions.',
#   'room': {'building_id': 60,
#            'building_name': 'Fisk Hall',
#            'id': 185,
#            'name': '306'},
#   'school': 'JOUR',
#   'seats': 14,
#   'section': '28',
#   'start_date': '2019-09-24',
#   'start_time': '13:00',
#   'subject': 'JOUR',
#   'term': '2019 Fall',
#   'title': 'Reporting & Writing',
#   'topic': None},
#  {'attributes': None,
#   'catalog_num': '201-2',
#   'class_num': 14600,
#   'component': 'LEC',
#   'course_components': [],
#   'course_descriptions': [],
#   'course_id': 17515,
#   'end_date': '2019-12-07',
#   'end_time': '11:20',
#   'id': 188161,
#   'instructor': {'address': None,
#                  'bio': None,
#                  'name': 'Aubrey Bates Baron',
#                  'office_hours': None,
#                  'phone': None},
#   'meeting_days': 'TuTh',
#   'overview': 'This course continues on the strong foundation created in JOUR '
#               '201-1 and significantly expands the base of multi-platform '
#               'tools needed for effective, relevant and engaging storytelling '
#               'for specific audiences. Instructors will guide students in the '
#               'continued development of reporting, interviewing, writing and '
#               'researching with a more sophisticated audience understanding '
#               'using text, audio, video and photos for print, broadcast and '
#               'the Web.',
#   'requirements': 'Enrollment Requirements: This section is currently closed '
#                   'to registration.  Please contact the department directly '
#                   'with any questions.',
#   'room': {'building_id': 60,
#            'building_name': 'Fisk Hall',
#            'id': 186,
#            'name': '307'},
#   'school': 'JOUR',
#   'seats': 18,
#   'section': '20',
#   'start_date': '2019-09-24',
#   'start_time': '09:30',
#   'subject': 'JOUR',
#   'term': '2019 Fall',
#   'title': 'Multimedia Storytelling',
#   'topic': None},
#  {'attributes': 'No Freshmen\n\n',
#   'catalog_num': '290-0',
#   'class_num': 14618,
#   'component': 'LEC',
#   'course_components': [],
#   'course_descriptions': [],
#   'course_id': 21896,
#   'end_date': '2019-12-07',
#   'end_time': '16:50',
#   'id': 188162,
#   'instructor': {'address': None,
#                  'bio': None,
#                  'name': 'Susan Yvonne Curtis',
#                  'office_hours': None,
#                  'phone': None},
#   'meeting_days': 'Tu',
#   'overview': 'This is an undergraduate class that explores the fundamental '
#               'tools of design, typographic contrast and color theory. You '
#               'will analyze current approaches to newspaper, magazine, web and '
#               'mobile design. We will discuss how planning, and developing '
#               'visual communication contribute to better design product. '
#               'Design is approach through writing and editing as a single '
#               'process in which the written and visual aspects of journalism '
#               'are given equal attention. Everyone is expected to take their '
#               'project to a creative and highly innovative solution. This is '
#               'achieved by following guidelines of good design process and '
#               'spending the necessary time on each project. This forces you to '
#               'think beyond the obvious and develop your ability to generate '
#               'ideas. All students are expected to present and defend their '
#               'design solutions to the class. This course is divided into '
#               'lectures, research, sketching, computer lab time, and '
#               'critiques.',
#   'requirements': 'Enrollment Requirements: Registration is reserved for '
#                   'Non-Medill sophomores, juniors and seniors.',
#   'room': None,
#   'school': 'JOUR',
#   'seats': 18,
#   'section': '20',
#   'start_date': '2019-09-24',
#   'start_time': '14:00',
#   'subject': 'JOUR',
#   'term': '2019 Fall',
#   'title': 'Building a Visual Brand (Non-Majors)',
#   'topic': None},
#  {'attributes': None,
#   'catalog_num': '301-0',
#   'class_num': 14557,
#   'component': 'LAB',
#   'course_components': [],
#   'course_descriptions': [],
#   'course_id': 930,
#   'end_date': '2019-12-07',
#   'end_time': '12:50',
#   'id': 188163,
#   'instructor': {'address': None,
#                  'bio': None,
#                  'name': 'Anne Elizabeth Ford',
#                  'office_hours': None,
#                  'phone': None},
#   'meeting_days': 'Fr',
#   'overview': 'In this Golden Age of Podcasting, many of the most successful '
#               'shows (The Hilarious World of Depression; The Mental Illness '
#               'Happy Hour; Terrible, Thanks for Asking) focus on mental '
#               'healthwhat it means, how it manifests, what resources are or '
#               "aren't available. This course will focus on audio reporting and "
#               'storytelling around issues of mental health. Students will '
#               'produce audio stories of their own and also work in groups to '
#               'create pilot episodes of podcasts. The course will require '
#               'reporting in the field.',
#   'requirements': 'Enrollment Requirements: Reserved for Medill Sophomores & '
#                   'Juniors',
#   'room': None,
#   'school': 'JOUR',
#   'seats': 15,
#   'section': '20',
#   'start_date': '2019-09-24',
#   'start_time': '09:00',
#   'subject': 'JOUR',
#   'term': '2019 Fall',
#   'title': 'Journalism in Practice',
#   'topic': 'Podcasting and Mental Health'},
#  {'attributes': 'Attendance at 1st class mandatory\n\n',
#   'catalog_num': '301-0',
#   'class_num': 14558,
#   'component': 'LAB',
#   'course_components': [],
#   'course_descriptions': [],
#   'course_id': 930,
#   'end_date': '2019-12-07',
#   'end_time': '16:50',
#   'id': 188164,
#   'instructor': {'address': None,
#                  'bio': None,
#                  'name': 'Jack C Doppelt',
#                  'office_hours': None,
#                  'phone': None},
#   'meeting_days': 'Tu',
#   'overview': 'Chicago is steeped in the immigrant tradition, alive with the '
#               'energy and natural chaos of recent arrivals to the city and '
#               'suburbs. It is also poised precariously to adjust to, respond '
#               'to, and be roiled by changes in immigration and refugee '
#               'policies and practices that accompany the Trump '
#               'administration. \n'
#               '\n'
#               'The Chicago area ranks 5th among metropolitan areas in '
#               'immigrant population. Chicago itself is more than 20% foreign '
#               'born; home to almost 600,000 immigrants and refugees. Suburban '
#               'Cook County is home to another 500,000 and growing.  \n'
#               '\n'
#               "Immigrant groups aren't monolithic. They have both divergent "
#               'and shared needs and interests. More than 50 percent of the '
#               'Chicago-area immigrants, for instance, were born in three '
#               'completely distinct parts of the world - Mexico, Poland, and '
#               'India. Moreover, the balance of the immigrant population is '
#               'even more diverse, with no country of origin comprising more '
#               'than five percent of the population. In some ways, though, '
#               'aggregate statistics or assumptions on the foreign born do more '
#               'to mask their characteristics and concerns than to illuminate '
#               'them. Through stories, we cross ethnic, cultural, neighborhood '
#               'and generational lines to document immigrant and refugee '
#               'experiences that are as varied as the people involved. Though '
#               'those stories surface every day, they often go untold, unshared '
#               'and unappreciated. \n'
#               '\n'
#               'This course will provide you opportunities to tell multimedia '
#               'immigrant and refugee stories for publication and to create a '
#               'social network across ethnic lines. By focusing on global '
#               'immigration and refugee phenomena, with a watchful eye on '
#               'national policy and the first 100 days of an administration '
#               'that seems to have targeted immigrants and refugees for special '
#               'concern and treatment, the course will expose you to the '
#               'communities where immigrants and refugees live and work, and in '
#               'partnership with ethnic media outlets in the city and suburbs '
#               'and with Immigrant Connect Chicago, an online network for '
#               'immigrants, refugees, their families and communities, you will '
#               'produce stories that matter and that animate the lives of those '
#               'who give you access to their experiences and families.',
#   'requirements': 'Enrollment Requirements: Reserved for Medill Sophomores & '
#                   'Juniors',
#   'room': {'building_id': 60,
#            'building_name': 'Fisk Hall',
#            'id': 187,
#            'name': '308'},
#   'school': 'JOUR',
#   'seats': 15,
#   'section': '21',
#   'start_date': '2019-09-24',
#   'start_time': '16:00',
#   'subject': 'JOUR',
#   'term': '2019 Fall',
#   'title': 'Journalism in Practice',
#   'topic': 'Connecting with Immigrants, Refugees and Multi-eth'},
#  {'attributes': 'Registration is By Application Only\n\n',
#   'catalog_num': '301-0',
#   'class_num': 14559,
#   'component': 'LAB',
#   'course_components': [],
#   'course_descriptions': [],
#   'course_id': 930,
#   'end_date': '2019-12-07',
#   'end_time': '16:50',
#   'id': 188165,
#   'instructor': {'address': None,
#                  'bio': None,
#                  'name': 'Owen R Youngman',
#                  'office_hours': None,
#                  'phone': None},
#   'meeting_days': 'TuTh',
#   'overview': 'Since the first days of the Internet, Chicago has been home to '
#               'fascinating startup businesses at the intersection of media and '
#               'technology. In this course, students will study the pros and '
#               'cons of locating an innovative new business in the Chicago '
#               'area; examine products and services that are being built and '
#               'tested here today; analyze the choices that are being made by '
#               'media companies, tech entrepreneurs, and investors; and observe '
#               'how the general public learns about these businesses. Course '
#               'work includes readings, lectures by faculty and guest speakers, '
#               'several field trips with associated reporting, and a final team '
#               'project. \n'
#               '\n'
#               ' \n'
#               '\n'
#               'Open only to students participating in the Bay Area Immersion '
#               'Program.',
#   'requirements': 'Enrollment Requirements: This section is currently closed '
#                   'to registration.  Please contact the department directly '
#                   'with any questions.',
#   'room': None,
#   'school': 'JOUR',
#   'seats': 28,
#   'section': '23',
#   'start_date': '2019-09-24',
#   'start_time': '14:00',
#   'subject': 'JOUR',
#   'term': '2019 Fall',
#   'title': 'Journalism in Practice',
#   'topic': "Media Innovation and Chicago's Startup Culture"},
#  {'attributes': None,
#   'catalog_num': '302-0',
#   'class_num': 17407,
#   'component': 'LEC',
#   'course_components': [],
#   'course_descriptions': [],
#   'course_id': 22430,
#   'end_date': '2019-12-07',
#   'end_time': '10:50',
#   'id': 190340,
#   'instructor': {'address': None,
#                  'bio': None,
#                  'name': 'Bradley Jay Hamm',
#                  'office_hours': None,
#                  'phone': None},
#   'meeting_days': 'TuTh',
#   'overview': 'A study of history can provide us with significant context and '
#               "knowledge so we can understand and evaluate today's journalism  "
#               'and how it may evolve in the future. \n'
#               '\n'
#               'Journalism, through the acts of seeking the truth and sharing '
#               'information with large audiences, is essential to the life of '
#               'our communities. As a great writer said, we depend upon the '
#               'media for a view of reality upon which the citizens can act.  \n'
#               '\n'
#               'This course will examine key ideas and people involved in the '
#               'development and evolution of journalism, along with projections '
#               'for the future.',
#   'requirements': 'Enrollment Requirements: Reserved for Medill Sophomores & '
#                   'Juniors',
#   'room': None,
#   'school': 'JOUR',
#   'seats': 60,
#   'section': '21',
#   'start_date': '2019-09-24',
#   'start_time': '09:00',
#   'subject': 'JOUR',
#   'term': '2019 Fall',
#   'title': 'Media History: Power, Protest and Passion',
#   'topic': 'Key Ideas in Journalism History'},
#  {'attributes': 'No Freshmen\n\n',
#   'catalog_num': '311-0',
#   'class_num': 14562,
#   'component': 'LAB',
#   'course_components': [],
#   'course_descriptions': [],
#   'course_id': 946,
#   'end_date': '2019-12-07',
#   'end_time': '16:50',
#   'id': 188166,
#   'instructor': {'address': None,
#                  'bio': None,
#                  'name': 'Richard Babcock',
#                  'office_hours': None,
#                  'phone': None},
#   'meeting_days': 'MoWe',
#   'overview': 'This course will help students develop the fundamental editing '
#               'abilities, editorial judgment and editorial management skills '
#               'required of an entry-level magazine editorin print,digital and '
#               'mobileplatforms.Story framing and pitching,editorialconcept '
#               'work, techniques for guiding writers, andopportunitiesto create '
#               'new magazine prototypes are all centralthemesof the '
#               'class.Students will gain insight into the magazine industry as '
#               'well astheskills and options needed forthewide variety of '
#               'career paths magazines offer.',
#   'requirements': 'Enrollment Requirements: Reserved for Medill Sophomores, '
#                   'Juniors & Seniors',
#   'room': {'building_id': 60,
#            'building_name': 'Fisk Hall',
#            'id': 187,
#            'name': '308'},
#   'school': 'JOUR',
#   'seats': 18,
#   'section': '21',
#   'start_date': '2019-09-24',
#   'start_time': '15:00',
#   'subject': 'JOUR',
#   'term': '2019 Fall',
#   'title': 'Media Presentation: Magazine',
#   'topic': None},
#  {'attributes': 'Prerequisites apply, see description\n\n',
#   'catalog_num': '320-0',
#   'class_num': 14560,
#   'component': 'LAB',
#   'course_components': [],
#   'course_descriptions': [{'desc': 'Pre-req: JOUR 301',
#                            'name': 'Registration Requirements'}],
#   'course_id': 942,
#   'end_date': '2019-12-07',
#   'end_time': '11:20',
#   'id': 188167,
#   'instructor': {'address': None,
#                  'bio': None,
#                  'name': 'Jill Blackman',
#                  'office_hours': None,
#                  'phone': None},
#   'meeting_days': 'TuTh',
#   'overview': 'Storytelling: Interactive News explores how storytelling '
#               'changes across various platforms-and how it must change when '
#               'interactivity causes narrative to be user-defined. This course '
#               'builds on the foundations of audio, photo, and video and adds '
#               'interactivity to the mix, enabling students to create and build '
#               'dynamic, interactive narratives for news and feature reporting. '
#               'Students will split their time between reporting, multimedia '
#               'editing, and learning open-web technologies (HTML, CSS, '
#               'JavaScript).',
#   'requirements': 'Enrollment Requirements: In order to register for this '
#                   'course you must have taken JOUR 301, JOUR 301-1 or JOUR '
#                   '384.',
#   'room': {'building_id': 60,
#            'building_name': 'Fisk Hall',
#            'id': 187,
#            'name': '308'},
#   'school': 'JOUR',
#   'seats': 18,
#   'section': '20',
#   'start_date': '2019-09-24',
#   'start_time': '09:30',
#   'subject': 'JOUR',
#   'term': '2019 Fall',
#   'title': 'Storytelling: Interactive News',
#   'topic': None},
#  {'attributes': 'Prerequisites apply, see description\n\n',
#   'catalog_num': '321-0',
#   'class_num': 14561,
#   'component': 'LAB',
#   'course_components': [],
#   'course_descriptions': [{'desc': 'Pre-req: JOUR 301',
#                            'name': 'Registration Requirements'}],
#   'course_id': 945,
#   'end_date': '2019-12-07',
#   'end_time': '11:50',
#   'id': 188168,
#   'instructor': {'address': None,
#                  'bio': None,
#                  'name': 'David Stephen Rodler Abrahamson',
#                  'office_hours': None,
#                  'phone': None},
#   'meeting_days': 'MoWe',
#   'overview': 'This course introduces students to narrative storytelling for '
#               'print, digital and mobile forms of magazines and explores '
#               'different writing techniques. Students will produce several '
#               'pieces including a well-researched and reported '
#               '2,500-3,000-word feature story suitable for publication in a '
#               'commercial outlet. Students will closely examine and '
#               'deconstruct stellar narrative from notable journalists and also '
#               'review and workshop their own pieces. The course aims to '
#               'challenge students to deliver memorable works of narrative '
#               'storytelling and inspire them to continue their growth as '
#               'reporters and writers.',
#   'requirements': 'Enrollment Requirements: In order to register for this '
#                   'course you must have taken JOUR 301, JOUR 301-1 or JOUR '
#                   '384.',
#   'room': {'building_id': 60,
#            'building_name': 'Fisk Hall',
#            'id': 185,
#            'name': '306'},
#   'school': 'JOUR',
#   'seats': 18,
#   'section': '20',
#   'start_date': '2019-09-24',
#   'start_time': '10:00',
#   'subject': 'JOUR',
#   'term': '2019 Fall',
#   'title': 'Storytelling: Magazine & Feature Writing',
#   'topic': None},
#  {'attributes': 'Prerequisites apply, see description\n\n',
#   'catalog_num': '322-0',
#   'class_num': 14564,
#   'component': 'LAB',
#   'course_components': [],
#   'course_descriptions': [{'desc': 'Pre-req: JOUR 301',
#                            'name': 'Registration Requirements'},
#                           {'desc': 'You will be responsible for your own '
#                                    'travel expenses to reporting locations, if '
#                                    'you incur them. That may include taxis, '
#                                    'rideshares, trains and other forms of '
#                                    'transport.',
#                            'name': 'Class Notes'},
#                           {'desc': 'One external hard drive - 1TB, USB 3.0 or '
#                                    'equivalent',
#                            'name': 'Class Materials (Required)'}],
#   'course_id': 952,
#   'end_date': '2019-12-07',
#   'end_time': '12:20',
#   'id': 188169,
#   'instructor': {'address': None,
#                  'bio': None,
#                  'name': 'Caryn B Ward',
#                  'office_hours': None,
#                  'phone': None},
#   'meeting_days': 'TuTh',
#   'overview': 'This Medill class is designed to teach video storytelling in '
#               'preparation for your journalism residency placement and beyond. '
#               'The course will emphasize a variety of research, writing and '
#               'field reporting techniques that will prepare you for the '
#               'challenges of working in a professional newsroom where video is '
#               'emphasized. In addition, we will consider in practice the '
#               'ethical implications of reporting, shooting, editing and '
#               'producing visual media. Deadline work will also be incorporated '
#               'in some assignments as well as a live shot exercise. Students '
#               'will practice on-camera skills primarily in the field.',
#   'requirements': 'Enrollment Requirements: In order to register for this '
#                   'course you must have taken JOUR 301, JOUR 301-1 or JOUR '
#                   '384.',
#   'room': None,
#   'school': 'JOUR',
#   'seats': 18,
#   'section': '20',
#   'start_date': '2019-09-24',
#   'start_time': '09:30',
#   'subject': 'JOUR',
#   'term': '2019 Fall',
#   'title': 'Storytelling: Video Reporting, Shooting, & Editing',
#   'topic': None},
#  {'attributes': 'No Freshmen\n\n',
#   'catalog_num': '333-0',
#   'class_num': 14619,
#   'component': 'LEC',
#   'course_components': [],
#   'course_descriptions': [],
#   'course_id': 22222,
#   'end_date': '2019-12-07',
#   'end_time': '14:20',
#   'id': 188170,
#   'instructor': {'address': None,
#                  'bio': None,
#                  'name': 'Mei-Ling Hopgood Reel',
#                  'office_hours': None,
#                  'phone': None},
#   'meeting_days': 'TuTh',
#   'overview': 'Thiswill be abilingualcourse that will explore the history, '
#               'current state and future of the English, Spanish '
#               'andbilingualmedia that seek to reach the growing Latino '
#               "audience. Students will immerse themselves in Chicago's vibrant "
#               'and diverse Latino community, and write and produce multimedia '
#               'stories and communications in Spanish and English.This course '
#               'is designed to empower students to understand and tell the '
#               'stories of Latin Americans in the United States, as well as in '
#               'Latin America, and reach these important audiences in the '
#               'languages that they use daily.',
#   'requirements': 'Enrollment Requirements: Registration is for students with '
#                   'a sophomore, junior, or senior standing.',
#   'room': {'building_id': 60,
#            'building_name': 'Fisk Hall',
#            'id': 186,
#            'name': '307'},
#   'school': 'JOUR',
#   'seats': 8,
#   'section': '20',
#   'start_date': '2019-09-24',
#   'start_time': '12:30',
#   'subject': 'JOUR',
#   'term': '2019 Fall',
#   'title': 'Bilingual Reporting',
#   'topic': None},
#  {'attributes': 'No Freshmen\n\n',
#   'catalog_num': '342-1',
#   'class_num': 14624,
#   'component': 'LEC',
#   'course_components': [],
#   'course_descriptions': [],
#   'course_id': 22750,
#   'end_date': '2019-12-07',
#   'end_time': '16:20',
#   'id': 188171,
#   'instructor': {'address': None,
#                  'bio': None,
#                  'name': 'Kristian J Hammond',
#                  'office_hours': None,
#                  'phone': None},
#   'meeting_days': 'TuTh',
#   'overview': 'Each quarter, multidisciplinary teams of students, faculty, and '
#               'professionals come together to collaborate in the Knight Lab '
#               'Studio to produce cutting-edge digital work, research, and '
#               'thought, innovating across every part of the media-making '
#               'process. The Lab places students together on diverse teams to '
#               'work on an important problem for the future of media, rapidly '
#               'moving beyond conversation and hypothesis to well-reasoned '
#               'action during the quarter. Our process combines user and '
#               'audience research, design thinking, critical and analytical '
#               'work, iterative building, storytelling, new technology, and a '
#               'healthy dose of experimentationoften within the confines of a '
# ...
#               'the end of Voting Rights Act protections against racial '
#               'discrimination in voting. \n'
#               '\n'
#               '- Immigration: Selective limits and bans on lawful migration '
#               'into the U.S., reducing the numbers and types of people allowed '
#               'to enter and stay in the country and become citizens who can '
#               'vote. \n'
#               '\n'
#               '- Voter suppression: Techniques used by states, ostensibly to '
#               'address potential vote fraud, such as requiring photo IDs; '
#               "purging voter rolls when registered voters don't vote in "
#               'consecutive elections; using unverified crosscheck lists to '
#               'create the impression of illegal duplicate voting; limiting '
#               'early voting; and closing targeted polling places, all of which '
#               'tend to disproportionately impact minorities, African-American '
#               'communities, lower-income residents, majority-Hispanic '
#               'districts, and senior citizens. \n'
#               '\n'
#               '- Census: Every ten years, the census bureau does its most '
#               'intensive count of the U.S. population. The data is used to '
#               'draw district boundaries for the purposes of determining '
#               'Congressional and state legislative maps, and one issue for '
#               'this coming 2020 census is the citizenship question, which we '
#               'will dissect to understand the relationship between the census, '
#               'demographic reality and elections to come. \n'
#               '\n'
#               '- Redistricting and gerrymandering: To date, it is legal for '
#               'politicians to draw district boundaries for partisan political '
#               'purposes, but not for racial reasons. The Supreme Court '
#               'recently sidestepped a decision on whether it should continue '
#               'to be legal. One consequence of political gerrymandering is it '
#               'allows for those in power who draw and approve the '
#               'redistricting maps to further entrench their political '
#               'ideologies and parties. \n'
#               '\n'
#               '- The Russians are coming. They came, they saw and they '
#               'corrupted. Why stop now?',
#   'requirements': 'Enrollment Requirements: REASON: Pre-registration is not '
#                   'allowed for this class. Please try again during regular '
#                   'registration.',
#   'room': None,
#   'school': 'JOUR',
#   'seats': 18,
#   'section': '25',
#   'start_date': '2019-09-24',
#   'start_time': None,
#   'subject': 'JOUR',
#   'term': '2019 Fall',
#   'title': 'Special Topics',
#   'topic': 'Social Justice Seminar'},
#  {'attributes': 'Course meets in San Francisco\n\n',
#   'catalog_num': '490-0',
#   'class_num': 14593,
#   'component': 'LAB',
#   'course_components': [],
#   'course_descriptions': [],
#   'course_id': 1007,
#   'end_date': '2019-12-07',
#   'end_time': '15:00',
#   'id': 188216,
#   'instructor': {'address': None,
#                  'bio': None,
#                  'name': '',
#                  'office_hours': None,
#                  'phone': None},
#   'meeting_days': 'Tu',
#   'overview': 'Students will explore innovation and business opportunities in '
#               "the center of the world's technology industry. Starting with "
#               'business fundamentals in media and technology industries, they '
#               'will learn to recognize opportunities for disruption, assess '
#               'the competitive landscape, and evaluate innovation strategies. '
#               'For the product ideas they are developing, they will identify '
#               'possible business models that would make them sustainable. The '
#               'course aims to inspire students to be the force of innovation '
#               'in media technology companies of any size, from the start-up '
#               'venture to the conglomerate.',
#   'requirements': 'Enrollment Requirements: REASON: Pre-registration is not '
#                   'allowed for this class. Please try again during regular '
#                   'registration.',
#   'room': None,
#   'school': 'JOUR',
#   'seats': 18,
#   'section': '24',
#   'start_date': '2019-09-24',
#   'start_time': '12:00',
#   'subject': 'JOUR',
#   'term': '2019 Fall',
#   'title': 'Special Topics',
#   'topic': 'The Business of Innovation'},
#  {'attributes': 'Course meets in San Francisco\n\n',
#   'catalog_num': '490-0',
#   'class_num': 14589,
#   'component': 'LAB',
#   'course_components': [],
#   'course_descriptions': [],
#   'course_id': 1007,
#   'end_date': '2019-12-07',
#   'end_time': '19:00',
#   'id': 188213,
#   'instructor': {'address': None,
#                  'bio': None,
#                  'name': '',
#                  'office_hours': None,
#                  'phone': None},
#   'meeting_days': 'Tu',
#   'overview': 'This course will give students without a software development '
#               'background a hands-on immersion in the toolsets, processes, and '
#               'programming languages used in the development of web '
#               'properties. \n'
#               '\n'
#               'The goal of the class is to prepare non-developers to work '
#               'successfully with developers - to learn what they need to know '
#               'to collaborate with technologists on a day-to-day basis. '
#               'Working in small teams in an agile software development '
#               'environment, students will work with version control tools, '
#               'collaborative programming, front-end web development languages '
#               '(HTML, CSS, Javascript), and frameworks including SASS, JQuery, '
#               'React, Ember and Angular.',
#   'requirements': 'Enrollment Requirements: REASON: Pre-registration is not '
#                   'allowed for this class. Please try again during regular '
#                   'registration.',
#   'room': None,
#   'school': 'JOUR',
#   'seats': 18,
#   'section': '21',
#   'start_date': '2019-09-24',
#   'start_time': '16:00',
#   'subject': 'JOUR',
#   'term': '2019 Fall',
#   'title': 'Special Topics',
#   'topic': 'Mobile Web Development for Media'},
#  {'attributes': 'Course meets in San Francisco\n\n',
#   'catalog_num': '490-0',
#   'class_num': 14590,
#   'component': 'LAB',
#   'course_components': [],
#   'course_descriptions': [],
#   'course_id': 1007,
#   'end_date': '2019-12-07',
#   'end_time': '13:00',
#   'id': 188214,
#   'instructor': {'address': None,
#                  'bio': None,
#                  'name': '',
#                  'office_hours': None,
#                  'phone': None},
#   'meeting_days': 'Mo',
#   'overview': 'This course focuses on imparting methods, theory, and practical '
#               'experience in the field of design research in order to help '
#               'define innovative products, services, and businesses in media '
#               'and journalism. Students will be exposed to interviewing and '
#               'observational techniques from anthropology, psychology, and '
#               'sociology; interpretive techniques from literature, psychology, '
#               'and business strategy; and creative methods and prototyping '
#               'techniques from engineering, design, marketing, and '
#               'advertising. By the end of this course, students will have a '
#               'firm grounding in how to study a small number of people, '
#               'uncover patterns in their thinking and behavior that point to '
#               'design opportunities for news media products and services, and '
#               'understand how to quickly test and improve ideas that solve for '
#               'these opportunities. This course has roots in, and a similar '
#               'arc to, fundamental design research courses taught in major '
#               'design programs, inside major corporations, by influential '
#               'consultancies, and in the most prominent startup accelerator, '
#               'Matter Ventures.',
#   'requirements': 'Enrollment Requirements: REASON: Pre-registration is not '
#                   'allowed for this class. Please try again during regular '
#                   'registration.',
#   'room': None,
#   'school': 'JOUR',
#   'seats': 18,
#   'section': '22',
#   'start_date': '2019-09-24',
#   'start_time': '10:00',
#   'subject': 'JOUR',
#   'term': '2019 Fall',
#   'title': 'Special Topics',
#   'topic': 'Design Thinking and Research for Media Products'},
#  {'attributes': 'Course meets in Washington DC\n\n',
#   'catalog_num': '490-0',
#   'class_num': 14588,
#   'component': 'LAB',
#   'course_components': [],
#   'course_descriptions': [],
#   'course_id': 1007,
#   'end_date': '2019-12-07',
#   'end_time': '20:50',
#   'id': 188212,
#   'instructor': {'address': None,
#                  'bio': None,
#                  'name': 'Jonathan J Allen',
#                  'office_hours': None,
#                  'phone': None},
#   'meeting_days': 'Mo',
#   'overview': 'This course aims to help you better understand the building '
#               'blocks that shape political campaigns and policy debates, such '
#               'as polls, advertising, debates, focus groups, fundraising, big '
#               'data, and free media (external or internal airtime on TV, '
#               'radio, digital platforms, etc.). This will be both a lecture '
#               'and reporting class with a series of assignments designed to '
#               'enhance your ability to write about those pieces of the '
#               'political process.',
#   'requirements': 'Enrollment Requirements: REASON: Pre-registration is not '
#                   'allowed for this class. Please try again during regular '
#                   'registration.',
#   'room': {'building_id': 126,
#            'building_name': 'Washington, DC Bureau',
#            'id': 705,
#            'name': ''},
#   'school': 'JOUR',
#   'seats': 20,
#   'section': '20',
#   'start_date': '2019-09-24',
#   'start_time': '18:00',
#   'subject': 'JOUR',
#   'term': '2019 Fall',
#   'title': 'Special Topics',
#   'topic': 'Politics in Practice: Covering Campaigns, Congress'},
#  {'attributes': None,
#   'catalog_num': '490-0',
#   'class_num': 14597,
#   'component': 'LAB',
#   'course_components': [],
#   'course_descriptions': [],
#   'course_id': 1007,
#   'end_date': '2019-12-07',
#   'end_time': None,
#   'id': 188219,
#   'instructor': {'address': None,
#                  'bio': None,
#                  'name': 'J. A. Adande',
#                  'office_hours': None,
#                  'phone': None},
#   'meeting_days': None,
#   'overview': 'Students will travel to L.A. for a week of events leading up to '
#               'the 67th annual NBA All-Star game on Sunday, Feb. 18. This trip '
#               'will teach students how to generate story ideas and cover the '
#               'week leading up to a major sporting event. Students will be '
#               'guided through the maze of press conferences, All-Star '
#               'competitions and charity events, reporting and producing text '
#               'and video stories for Medill Reports and possible other '
#               'sites. \n'
#               '  \n'
#               'On this program, you will:  \n'
#               '\n'
#               '- Learn interviewing and reporting strategies for event '
#               'coverage \n'
#               '- Divide into teams before the trip and develop specific '
#               'reporting and coverage goals \n'
#               "- Work with your beat editor and the trip's faculty leader "
#               'before the trip to research two or three story ideas, identify '
#               'sources and make advance contacts \n'
#               '- Report in teams in L.A. on the issue(s) and in the media your '
#               'team has chosen \n'
#               '- Produce a reporting project that, it is hoped, will be '
#               'published either during or after the trip',
#   'requirements': 'Enrollment Requirements: REASON: Pre-registration is not '
#                   'allowed for this class. Please try again during regular '
#                   'registration.',
#   'room': None,
#   'school': 'JOUR',
#   'seats': 18,
#   'section': '28',
#   'start_date': '2019-09-24',
#   'start_time': None,
#   'subject': 'JOUR',
#   'term': '2019 Fall',
#   'title': 'Special Topics',
#   'topic': 'Sports Reporting Seminar'},
#  {'attributes': 'Course meets in San Francisco\n\n',
#   'catalog_num': '490-0',
#   'class_num': 14592,
#   'component': 'LAB',
#   'course_components': [],
#   'course_descriptions': [],
#   'course_id': 1007,
#   'end_date': '2019-12-07',
#   'end_time': '17:00',
#   'id': 188215,
#   'instructor': {'address': None,
#                  'bio': None,
#                  'name': '',
#                  'office_hours': None,
#                  'phone': None},
#   'meeting_days': 'ThFr',
#   'overview': 'For one full quarter, students will work two or three days a '
#               'week at a Bay Area company, focused on building media/tech '
#               'products and/or making them more successful. The goal is for '
#               'students to get hands-on experience that helps them develop new '
#               'skills, sharpen existing ones and develop a deeper '
#               'understanding of media innovation and product development. '
#               'Students will file weekly reflections on their internships and '
#               'meet several times during the quarter with the professor and '
#               'other students to discuss their experiences.  Each student will '
#               'be expected to present once to the group about their '
#               'experiences and/or lessons learned, and to write a reflective '
#               'assessment at the end of the quarter about what they learned '
#               'from the internship.',
#   'requirements': 'Enrollment Requirements: REASON: Pre-registration is not '
#                   'allowed for this class. Please try again during regular '
#                   'registration.',
#   'room': None,
#   'school': 'JOUR',
#   'seats': 18,
#   'section': '23',
#   'start_date': '2019-09-24',
#   'start_time': '09:00',
#   'subject': 'JOUR',
#   'term': '2019 Fall',
#   'title': 'Special Topics',
#   'topic': 'Practicum in Media and Technology'},
#  {'attributes': None,
#   'catalog_num': '498-0',
#   'class_num': 14621,
#   'component': 'PRA',
#   'course_components': [],
#   'course_descriptions': [],
#   'course_id': 22323,
#   'end_date': '2019-12-07',
#   'end_time': None,
#   'id': 188221,
#   'instructor': {'address': None,
#                  'bio': None,
#                  'name': '',
#                  'office_hours': None,
#                  'phone': None},
#   'meeting_days': None,
#   'overview': None,
#   'requirements': 'Enrollment Requirements: REASON: Pre-registration is not '
#                   'allowed for this class. Please try again during regular '
#                   'registration.',
#   'room': {'building_id': 118, 'building_name': 'TBA', 'id': 545, 'name': ''},
#   'school': 'JOUR',
#   'seats': 10,
#   'section': '20',
#   'start_date': '2019-09-24',
#   'start_time': None,
#   'subject': 'JOUR',
#   'term': '2019 Fall',
#   'title': 'Practicum',
#   'topic': None},
#  {'attributes': None,
#   'catalog_num': '499-2',
#   'class_num': 14587,
#   'component': 'PRA',
#   'course_components': [],
#   'course_descriptions': [],
#   'course_id': 1006,
#   'end_date': '2019-12-07',
#   'end_time': None,
#   'id': 188222,
#   'instructor': {'address': None,
#                  'bio': None,
#                  'name': 'Dorina Aguilar Rasmussen',
#                  'office_hours': None,
#                  'phone': None},
#   'meeting_days': None,
#   'overview': None,
#   'requirements': 'Enrollment Requirements: REASON: Pre-registration is not '
#                   'allowed for this class. Please try again during regular '
#                   'registration.',
#   'room': {'building_id': 118, 'building_name': 'TBA', 'id': 545, 'name': ''},
#   'school': 'JOUR',
#   'seats': 30,
#   'section': '20',
#   'start_date': '2019-09-24',
#   'start_time': None,
#   'subject': 'JOUR',
#   'term': '2019 Fall',
#   'title': 'Internship',
#   'topic': None}]

# %%
pprint(detailedschoolarray)
# Out:
# [{'name': 'Medill School of Journalism',
#   'subjects': [{'courses': [{'catalog_num': '300-0',
#                              'class_num': 14670,
#                              'course_id': 18269,
#                              'id': 188088,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Introduction to Integrated Marketing '
#                                       'Communications'},
#                             {'catalog_num': '301-0',
#                              'class_num': 14668,
#                              'course_id': 18268,
#                              'id': 188089,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Consumer Insight'},
#                             {'catalog_num': '301-0',
#                              'class_num': 14669,
#                              'course_id': 18268,
#                              'id': 188090,
#                              'school': 'JOUR',
#                              'section': '21',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Consumer Insight'},
#                             {'catalog_num': '302-0',
#                              'class_num': 14627,
#                              'course_id': 894,
#                              'id': 188091,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Research for Marketing Communications'},
#                             {'catalog_num': '302-0',
#                              'class_num': 14629,
#                              'course_id': 894,
#                              'id': 188093,
#                              'school': 'JOUR',
#                              'section': '22',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Research for Marketing Communications'},
#                             {'catalog_num': '302-0',
#                              'class_num': 14628,
#                              'course_id': 894,
#                              'id': 188092,
#                              'school': 'JOUR',
#                              'section': '21',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Research for Marketing Communications'},
#                             {'catalog_num': '303-0',
#                              'class_num': 14687,
#                              'course_id': 20526,
#                              'id': 188094,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Integrated Marketing Communications '
#                                       'Strategy'},
#                             {'catalog_num': '303-0',
#                              'class_num': 14688,
#                              'course_id': 20526,
#                              'id': 188095,
#                              'school': 'JOUR',
#                              'section': '21',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Integrated Marketing Communications '
#                                       'Strategy'},
#                             {'catalog_num': '304-0',
#                              'class_num': 17193,
#                              'course_id': 895,
#                              'id': 188096,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Media and Message Delivery'},
#                             {'catalog_num': '306-0',
#                              'class_num': 14674,
#                              'course_id': 18464,
#                              'id': 188097,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Strategic Communications'},
#                             {'catalog_num': '306-0',
#                              'class_num': 14675,
#                              'course_id': 18464,
#                              'id': 188098,
#                              'school': 'JOUR',
#                              'section': '21',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Strategic Communications'},
#                             {'catalog_num': '307-0',
#                              'class_num': 14676,
#                              'course_id': 18539,
#                              'id': 188099,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Digital, Social and Mobile Marketing'},
#                             {'catalog_num': '310-0',
#                              'class_num': 14677,
#                              'course_id': 18546,
#                              'id': 188100,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Integrated Marketing and Communication '
#                                       'Law, Policy and Ethics'},
#                             {'catalog_num': '400-0',
#                              'class_num': 14644,
#                              'course_id': 904,
#                              'id': 188101,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Consumer Insight'},
#                             {'catalog_num': '401-0',
#                              'class_num': 14635,
#                              'course_id': 900,
#                              'id': 188103,
#                              'school': 'JOUR',
#                              'section': '30',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Marketing Research'},
#                             {'catalog_num': '401-0',
#                              'class_num': 14634,
#                              'course_id': 900,
#                              'id': 188102,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Marketing Research'},
#                             {'catalog_num': '401-6',
#                              'class_num': 14679,
#                              'course_id': 20295,
#                              'id': 188104,
#                              'school': 'JOUR',
#                              'section': '40',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Marketing Research'},
#                             {'catalog_num': '402-0',
#                              'class_num': 14630,
#                              'course_id': 899,
#                              'id': 188105,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Financial Accounting'},
#                             {'catalog_num': '403-0',
#                              'class_num': 14640,
#                              'course_id': 901,
#                              'id': 188107,
#                              'school': 'JOUR',
#                              'section': '30',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'IMC I: Marketing Management'},
#                             {'catalog_num': '403-0',
#                              'class_num': 14639,
#                              'course_id': 901,
#                              'id': 188106,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'IMC I: Marketing Management'},
#                             {'catalog_num': '403-6',
#                              'class_num': 14680,
#                              'course_id': 20297,
#                              'id': 188108,
#                              'school': 'JOUR',
#                              'section': '40',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'IMC I: Marketing Management'},
#                             {'catalog_num': '404-6',
#                              'class_num': 14683,
#                              'course_id': 20302,
#                              'id': 188109,
#                              'school': 'JOUR',
#                              'section': '40',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'IMC II: Strategic Process'},
#                             {'catalog_num': '410-0',
#                              'class_num': 17321,
#                              'course_id': 922,
#                              'id': 188110,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'IMC Law, Policy & Ethics'},
#                             {'catalog_num': '410-6',
#                              'class_num': 14682,
#                              'course_id': 20301,
#                              'id': 188111,
#                              'school': 'JOUR',
#                              'section': '40',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'IMC Law, Policy and Ethics'},
#                             {'catalog_num': '411-6',
#                              'class_num': 14681,
#                              'course_id': 20300,
#                              'id': 188112,
#                              'school': 'JOUR',
#                              'section': '40',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Managing Integration'},
#                             {'catalog_num': '412-0',
#                              'class_num': 14678,
#                              'course_id': 19374,
#                              'id': 188113,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Global Perspectives, Asia'},
#                             {'catalog_num': '413-0',
#                              'class_num': 14694,
#                              'course_id': 23185,
#                              'id': 188114,
#                              'school': 'JOUR',
#                              'section': '30',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'IMC Leadership'},
#                             {'catalog_num': '422-0',
#                              'class_num': 14689,
#                              'course_id': 21041,
#                              'id': 188115,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Building Brands with Creative Ideas'},
#                             {'catalog_num': '424-0',
#                              'class_num': 17191,
#                              'course_id': 23187,
#                              'id': 188117,
#                              'school': 'JOUR',
#                              'section': '30',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Shopper Marketing'},
#                             {'catalog_num': '424-0',
#                              'class_num': 14696,
#                              'course_id': 23187,
#                              'id': 188116,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Shopper Marketing'},
#                             {'catalog_num': '425-0',
#                              'class_num': 17265,
#                              'course_id': 23271,
#                              'id': 188119,
#                              'school': 'JOUR',
#                              'section': '30',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Global Perspectives, Global Branding, '
#                                       'London'},
#                             {'catalog_num': '425-0',
#                              'class_num': 17264,
#                              'course_id': 23271,
#                              'id': 188118,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Global Perspectives, Global Branding, '
#                                       'London'},
#                             {'catalog_num': '426-0',
#                              'class_num': 14697,
#                              'course_id': 23189,
#                              'id': 188120,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Customer Value Innovation'},
#                             {'catalog_num': '427-0',
#                              'class_num': 17136,
#                              'course_id': 23272,
#                              'id': 188121,
#                              'school': 'JOUR',
#                              'section': '30',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Digital Strategy'},
#                             {'catalog_num': '438-6',
#                              'class_num': 14685,
#                              'course_id': 20309,
#                              'id': 188122,
#                              'school': 'JOUR',
#                              'section': '40',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Segmentation and Lifetime Value'},
#                             {'catalog_num': '443-0',
#                              'class_num': 14649,
#                              'course_id': 914,
#                              'id': 188123,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Investor Relations'},
#                             {'catalog_num': '444-0',
#                              'class_num': 14667,
#                              'course_id': 18189,
#                              'id': 188124,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Crisis Communications'},
#                             {'catalog_num': '444-6',
#                              'class_num': 14684,
#                              'course_id': 20307,
#                              'id': 188125,
#                              'school': 'JOUR',
#                              'section': '40',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Crisis Communications'},
#                             {'catalog_num': '453-0',
#                              'class_num': 17192,
#                              'course_id': 23277,
#                              'id': 188126,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Media Decisions'},
#                             {'catalog_num': '464-0',
#                              'class_num': 14648,
#                              'course_id': 907,
#                              'id': 188127,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Marketing Mix Analysis'},
#                             {'catalog_num': '465-0',
#                              'class_num': 14698,
#                              'course_id': 23279,
#                              'id': 188128,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Marketing Models II'},
#                             {'catalog_num': '466-0',
#                              'class_num': 14699,
#                              'course_id': 23280,
#                              'id': 188129,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Machine Learning II'},
#                             {'catalog_num': '482-0',
#                              'class_num': 14672,
#                              'course_id': 18368,
#                              'id': 188130,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Strategic Planning in an E-Commerce '
#                                       'Environment'},
#                             {'catalog_num': '484-0',
#                              'class_num': 14666,
#                              'course_id': 18188,
#                              'id': 188131,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Digital, Social and Mobile Marketing'},
#                             {'catalog_num': '497-0',
#                              'class_num': 14691,
#                              'course_id': 22675,
#                              'id': 188133,
#                              'school': 'JOUR',
#                              'section': '21',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Exchange Program - Study Abroad Course'},
#                             {'catalog_num': '497-0',
#                              'class_num': 14693,
#                              'course_id': 22675,
#                              'id': 188135,
#                              'school': 'JOUR',
#                              'section': '23',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Exchange Program - Study Abroad Course'},
#                             {'catalog_num': '497-0',
#                              'class_num': 14692,
#                              'course_id': 22675,
#                              'id': 188134,
#                              'school': 'JOUR',
#                              'section': '22',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Exchange Program - Study Abroad Course'},
#                             {'catalog_num': '497-0',
#                              'class_num': 14690,
#                              'course_id': 22675,
#                              'id': 188132,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Exchange Program - Study Abroad Course'},
#                             {'catalog_num': '498-0',
#                              'class_num': 14659,
#                              'course_id': 924,
#                              'id': 188144,
#                              'school': 'JOUR',
#                              'section': '30',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Practicum'},
#                             {'catalog_num': '498-0',
#                              'class_num': 14654,
#                              'course_id': 924,
#                              'id': 188139,
#                              'school': 'JOUR',
#                              'section': '24',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Practicum'},
#                             {'catalog_num': '498-0',
#                              'class_num': 14656,
#                              'course_id': 924,
#                              'id': 188141,
#                              'school': 'JOUR',
#                              'section': '26',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Practicum'},
#                             {'catalog_num': '498-0',
#                              'class_num': 14700,
#                              'course_id': 924,
#                              'id': 188142,
#                              'school': 'JOUR',
#                              'section': '28',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Practicum'},
#                             {'catalog_num': '498-0',
#                              'class_num': 14655,
#                              'course_id': 924,
#                              'id': 188140,
#                              'school': 'JOUR',
#                              'section': '25',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Practicum'},
#                             {'catalog_num': '498-0',
#                              'class_num': 14657,
#                              'course_id': 924,
#                              'id': 188145,
#                              'school': 'JOUR',
#                              'section': '31',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Practicum'},
#                             {'catalog_num': '498-0',
#                              'class_num': 14658,
#                              'course_id': 924,
#                              'id': 188143,
#                              'school': 'JOUR',
#                              'section': '29',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Practicum'},
#                             {'catalog_num': '498-0',
#                              'class_num': 14653,
#                              'course_id': 924,
#                              'id': 188138,
#                              'school': 'JOUR',
#                              'section': '23',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Practicum'},
#                             {'catalog_num': '498-0',
#                              'class_num': 14652,
#                              'course_id': 924,
#                              'id': 188137,
#                              'school': 'JOUR',
#                              'section': '22',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Practicum'},
#                             {'catalog_num': '498-0',
#                              'class_num': 14650,
#                              'course_id': 924,
#                              'id': 188136,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Practicum'},
#                             {'catalog_num': '498-6',
#                              'class_num': 14686,
#                              'course_id': 20311,
#                              'id': 188146,
#                              'school': 'JOUR',
#                              'section': '40',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Practicum'},
#                             {'catalog_num': '499-2',
#                              'class_num': 14673,
#                              'course_id': 18430,
#                              'id': 188147,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'IMC',
#                              'term': '2019 Fall',
#                              'title': 'Internship'}],
#                 'name': 'Integrated Marketing Communications',
#                 'symbol': 'IMC'},
#                {'courses': [{'catalog_num': '201-1',
#                              'class_num': 16068,
#                              'course_id': 926,
#                              'id': 188160,
#                              'school': 'JOUR',
#                              'section': '32',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Reporting & Writing'},
#                             {'catalog_num': '201-1',
#                              'class_num': 16174,
#                              'course_id': 926,
#                              'id': 188158,
#                              'school': 'JOUR',
#                              'section': '30',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Reporting & Writing'},
#                             {'catalog_num': '201-1',
#                              'class_num': 16168,
#                              'course_id': 926,
#                              'id': 188152,
#                              'school': 'JOUR',
#                              'section': '24',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Reporting & Writing'},
#                             {'catalog_num': '201-1',
#                              'class_num': 16170,
#                              'course_id': 926,
#                              'id': 188154,
#                              'school': 'JOUR',
#                              'section': '26',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Reporting & Writing'},
#                             {'catalog_num': '201-1',
#                              'class_num': 14555,
#                              'course_id': 926,
#                              'id': 188148,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Reporting & Writing'},
#                             {'catalog_num': '201-1',
#                              'class_num': 16066,
#                              'course_id': 926,
#                              'id': 188150,
#                              'school': 'JOUR',
#                              'section': '22',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Reporting & Writing'},
#                             {'catalog_num': '201-1',
#                              'class_num': 16067,
#                              'course_id': 926,
#                              'id': 188151,
#                              'school': 'JOUR',
#                              'section': '23',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Reporting & Writing'},
#                             {'catalog_num': '201-1',
#                              'class_num': 14556,
#                              'course_id': 926,
#                              'id': 188149,
#                              'school': 'JOUR',
#                              'section': '21',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Reporting & Writing'},
#                             {'catalog_num': '201-1',
#                              'class_num': 16169,
#                              'course_id': 926,
#                              'id': 188153,
#                              'school': 'JOUR',
#                              'section': '25',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Reporting & Writing'},
#                             {'catalog_num': '201-1',
#                              'class_num': 16171,
#                              'course_id': 926,
#                              'id': 188155,
#                              'school': 'JOUR',
#                              'section': '27',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Reporting & Writing'},
#                             {'catalog_num': '201-1',
#                              'class_num': 16173,
#                              'course_id': 926,
#                              'id': 188157,
#                              'school': 'JOUR',
#                              'section': '29',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Reporting & Writing'},
#                             {'catalog_num': '201-1',
#                              'class_num': 16175,
#                              'course_id': 926,
#                              'id': 188159,
#                              'school': 'JOUR',
#                              'section': '31',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Reporting & Writing'},
#                             {'catalog_num': '201-1',
#                              'class_num': 16172,
#                              'course_id': 926,
#                              'id': 188156,
#                              'school': 'JOUR',
#                              'section': '28',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Reporting & Writing'},
#                             {'catalog_num': '201-2',
#                              'class_num': 14600,
#                              'course_id': 17515,
#                              'id': 188161,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Multimedia Storytelling'},
#                             {'catalog_num': '290-0',
#                              'class_num': 14618,
#                              'course_id': 21896,
#                              'id': 188162,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Building a Visual Brand (Non-Majors)'},
#                             {'catalog_num': '301-0',
#                              'class_num': 14557,
#                              'course_id': 930,
#                              'id': 188163,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Journalism in Practice'},
#                             {'catalog_num': '301-0',
#                              'class_num': 14558,
#                              'course_id': 930,
#                              'id': 188164,
#                              'school': 'JOUR',
#                              'section': '21',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Journalism in Practice'},
#                             {'catalog_num': '301-0',
#                              'class_num': 14559,
#                              'course_id': 930,
#                              'id': 188165,
#                              'school': 'JOUR',
#                              'section': '23',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Journalism in Practice'},
#                             {'catalog_num': '302-0',
#                              'class_num': 17407,
#                              'course_id': 22430,
#                              'id': 190340,
#                              'school': 'JOUR',
#                              'section': '21',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Media History: Power, Protest and '
#                                       'Passion'},
#                             {'catalog_num': '311-0',
#                              'class_num': 14562,
#                              'course_id': 946,
#                              'id': 188166,
#                              'school': 'JOUR',
#                              'section': '21',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Media Presentation: Magazine'},
#                             {'catalog_num': '320-0',
#                              'class_num': 14560,
#                              'course_id': 942,
#                              'id': 188167,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Storytelling: Interactive News'},
#                             {'catalog_num': '321-0',
#                              'class_num': 14561,
#                              'course_id': 945,
#                              'id': 188168,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Storytelling: Magazine & Feature '
#                                       'Writing'},
#                             {'catalog_num': '322-0',
#                              'class_num': 14564,
#                              'course_id': 952,
#                              'id': 188169,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Storytelling: Video Reporting, '
#                                       'Shooting, & Editing'},
#                             {'catalog_num': '333-0',
#                              'class_num': 14619,
#                              'course_id': 22222,
#                              'id': 188170,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Bilingual Reporting'},
#                             {'catalog_num': '342-1',
#                              'class_num': 14624,
#                              'course_id': 22750,
#                              'id': 188171,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Knight Lab'},
#                             {'catalog_num': '347-0',
#                              'class_num': 14622,
#                              'course_id': 22411,
#                              'id': 188172,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Journalism Residency'},
#                             {'catalog_num': '348-0',
#                              'class_num': 14626,
#                              'course_id': 22811,
#                              'id': 188173,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Journalism Residency'},
#                             {'catalog_num': '353-0',
#                              'class_num': 16505,
#                              'course_id': 21892,
#                              'id': 188174,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Dilemmas of American Power'},
#                             {'catalog_num': '370-0',
#                              'class_num': 14565,
#                              'course_id': 959,
#                              'id': 188175,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Media Law & Ethics'},
#                             {'catalog_num': '373-0',
#                              'class_num': 14566,
#                              'course_id': 960,
#                              'id': 188176,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Investigative Journalism'},
#                             {'catalog_num': '376-0',
#                              'class_num': 14567,
#                              'course_id': 963,
#                              'id': 188177,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Media Design'},
#                             {'catalog_num': '378-0',
#                              'class_num': 14599,
#                              'course_id': 16097,
#                              'id': 188178,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Introduction to Photojournalism'},
#                             {'catalog_num': '388-0',
#                              'class_num': 14568,
#                              'course_id': 968,
#                              'id': 188179,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Internship'},
#                             {'catalog_num': '390-0',
#                              'class_num': 17150,
#                              'course_id': 969,
#                              'id': 188188,
#                              'school': 'JOUR',
#                              'section': '29',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Special Topics'},
#                             {'catalog_num': '390-0',
#                              'class_num': 14571,
#                              'course_id': 969,
#                              'id': 188182,
#                              'school': 'JOUR',
#                              'section': '22',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Special Topics'},
#                             {'catalog_num': '390-0',
#                              'class_num': 14575,
#                              'course_id': 969,
#                              'id': 188185,
#                              'school': 'JOUR',
#                              'section': '26',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Special Topics'},
#                             {'catalog_num': '390-0',
#                              'class_num': 17385,
#                              'course_id': 969,
#                              'id': 188184,
#                              'school': 'JOUR',
#                              'section': '25',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Special Topics'},
#                             {'catalog_num': '390-0',
#                              'class_num': 14570,
#                              'course_id': 969,
#                              'id': 188181,
#                              'school': 'JOUR',
#                              'section': '21',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Special Topics'},
#                             {'catalog_num': '390-0',
#                              'class_num': 14569,
#                              'course_id': 969,
#                              'id': 188180,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Special Topics'},
#                             {'catalog_num': '390-0',
#                              'class_num': 17149,
#                              'course_id': 969,
#                              'id': 188183,
#                              'school': 'JOUR',
#                              'section': '23',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Special Topics'},
#                             {'catalog_num': '390-0',
#                              'class_num': 16305,
#                              'course_id': 969,
#                              'id': 188186,
#                              'school': 'JOUR',
#                              'section': '27',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Special Topics'},
#                             {'catalog_num': '390-0',
#                              'class_num': 17148,
#                              'course_id': 969,
#                              'id': 188187,
#                              'school': 'JOUR',
#                              'section': '28',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Special Topics'},
#                             {'catalog_num': '400-0',
#                              'class_num': 14609,
#                              'course_id': 19985,
#                              'id': 188191,
#                              'school': 'JOUR',
#                              'section': '22',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Foundations of Video Journalism'},
#                             {'catalog_num': '400-0',
#                              'class_num': 14606,
#                              'course_id': 19985,
#                              'id': 188189,
#                              'school': 'JOUR',
#                              'section': '20',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Foundations of Video Journalism'},
#                             {'catalog_num': '400-0',
#                              'class_num': 14610,
#                              'course_id': 19985,
#                              'id': 188192,
#                              'school': 'JOUR',
#                              'section': '23',
#                              'subject': 'JOUR',
#                              'term': '2019 Fall',
#                              'title': 'Foundations of Video Journalism'},
#                             {'catalog_num': '400-0',
#                              'class_num': 14607,
#                              'course_id': 19985,
#                              'id': 188190,
#                              'school': 'JOUR',
# ...
#                             {'catalog_num': '395-0',
#                              'class_num': 13596,
#                              'course_id': 3194,
#                              'id': 190301,
#                              'school': 'WCAS',
#                              'section': '1',
#                              'subject': 'SPANISH',
#                              'term': '2019 Fall',
#                              'title': 'Topics in Latin American, Latina and '
#                                       'Latino, and/or Iberian Cultures'},
#                             {'catalog_num': '397-0',
#                              'class_num': 17405,
#                              'course_id': 3198,
#                              'id': 190354,
#                              'school': 'WCAS',
#                              'section': '2',
#                              'subject': 'SPANISH',
#                              'term': '2019 Fall',
#                              'title': 'Topics in Latin American, Latina and '
#                                       'Latino, and Iberian Literatures and '
#                                       'Cultures'},
#                             {'catalog_num': '397-0',
#                              'class_num': 13597,
#                              'course_id': 3198,
#                              'id': 190302,
#                              'school': 'WCAS',
#                              'section': '1',
#                              'subject': 'SPANISH',
#                              'term': '2019 Fall',
#                              'title': 'Topics in Latin American, Latina and '
#                                       'Latino, and Iberian Literatures and '
#                                       'Cultures'}],
#                 'name': 'Spanish',
#                 'symbol': 'SPANISH'},
#                {'courses': [{'catalog_num': '415-0',
#                              'class_num': 17290,
#                              'course_id': 20257,
#                              'id': 190303,
#                              'school': 'WCAS',
#                              'section': '1',
#                              'subject': 'SPANPORT',
#                              'term': '2019 Fall',
#                              'title': 'Studies in 19th Century Literatures & '
#                                       'Cultures'},
#                             {'catalog_num': '480-0',
#                              'class_num': 13617,
#                              'course_id': 20255,
#                              'id': 190304,
#                              'school': 'WCAS',
#                              'section': '1',
#                              'subject': 'SPANPORT',
#                              'term': '2019 Fall',
#                              'title': 'Topics in Latin American Literature '
#                                       'and/or Iberian Literatures & Culture'},
#                             {'catalog_num': '570-0',
#                              'class_num': 13636,
#                              'course_id': 20806,
#                              'id': 190305,
#                              'school': 'WCAS',
#                              'section': '20',
#                              'subject': 'SPANPORT',
#                              'term': '2019 Fall',
#                              'title': 'Teaching Assistantship and '
#                                       'Methodologies'},
#                             {'catalog_num': '570-0',
#                              'class_num': 13647,
#                              'course_id': 20806,
#                              'id': 190306,
#                              'school': 'WCAS',
#                              'section': '21',
#                              'subject': 'SPANPORT',
#                              'term': '2019 Fall',
#                              'title': 'Teaching Assistantship and '
#                                       'Methodologies'},
#                             {'catalog_num': '570-0',
#                              'class_num': 13637,
#                              'course_id': 20806,
#                              'id': 190307,
#                              'school': 'WCAS',
#                              'section': '22',
#                              'subject': 'SPANPORT',
#                              'term': '2019 Fall',
#                              'title': 'Teaching Assistantship and '
#                                       'Methodologies'},
#                             {'catalog_num': '570-0',
#                              'class_num': 13638,
#                              'course_id': 20806,
#                              'id': 190308,
#                              'school': 'WCAS',
#                              'section': '23',
#                              'subject': 'SPANPORT',
#                              'term': '2019 Fall',
#                              'title': 'Teaching Assistantship and '
#                                       'Methodologies'},
#                             {'catalog_num': '570-0',
#                              'class_num': 13639,
#                              'course_id': 20806,
#                              'id': 190309,
#                              'school': 'WCAS',
#                              'section': '24',
#                              'subject': 'SPANPORT',
#                              'term': '2019 Fall',
#                              'title': 'Teaching Assistantship and '
#                                       'Methodologies'},
#                             {'catalog_num': '570-0',
#                              'class_num': 13640,
#                              'course_id': 20806,
#                              'id': 190310,
#                              'school': 'WCAS',
#                              'section': '25',
#                              'subject': 'SPANPORT',
#                              'term': '2019 Fall',
#                              'title': 'Teaching Assistantship and '
#                                       'Methodologies'},
#                             {'catalog_num': '570-0',
#                              'class_num': 13641,
#                              'course_id': 20806,
#                              'id': 190311,
#                              'school': 'WCAS',
#                              'section': '27',
#                              'subject': 'SPANPORT',
#                              'term': '2019 Fall',
#                              'title': 'Teaching Assistantship and '
#                                       'Methodologies'},
#                             {'catalog_num': '570-0',
#                              'class_num': 13643,
#                              'course_id': 20806,
#                              'id': 190312,
#                              'school': 'WCAS',
#                              'section': '29',
#                              'subject': 'SPANPORT',
#                              'term': '2019 Fall',
#                              'title': 'Teaching Assistantship and '
#                                       'Methodologies'}],
#                 'name': 'Spanish and Portuguese',
#                 'symbol': 'SPANPORT'},
#                {'courses': [{'catalog_num': '101-6',
#                              'class_num': 13908,
#                              'course_id': 3386,
#                              'id': 190313,
#                              'school': 'WCAS',
#                              'section': '1',
#                              'subject': 'STAT',
#                              'term': '2019 Fall',
#                              'title': 'First-Year Seminar'},
#                             {'catalog_num': '202-0',
#                              'class_num': 13909,
#                              'course_id': 3388,
#                              'id': 190314,
#                              'school': 'WCAS',
#                              'section': '20',
#                              'subject': 'STAT',
#                              'term': '2019 Fall',
#                              'title': 'Introduction to Statistics'},
#                             {'catalog_num': '210-0',
#                              'class_num': 13911,
#                              'course_id': 3390,
#                              'id': 190315,
#                              'school': 'WCAS',
#                              'section': '20',
#                              'subject': 'STAT',
#                              'term': '2019 Fall',
#                              'title': 'Introductory Statistics for the Social '
#                                       'Sciences'},
#                             {'catalog_num': '301-1',
#                              'class_num': 13948,
#                              'course_id': 21791,
#                              'id': 190316,
#                              'school': 'WCAS',
#                              'section': '20',
#                              'subject': 'STAT',
#                              'term': '2019 Fall',
#                              'title': 'Data Science 1'},
#                             {'catalog_num': '320-1',
#                              'class_num': 13944,
#                              'course_id': 13203,
#                              'id': 190318,
#                              'school': 'WCAS',
#                              'section': '21',
#                              'subject': 'STAT',
#                              'term': '2019 Fall',
#                              'title': 'Statistical Theory & Methods 1'},
#                             {'catalog_num': '320-1',
#                              'class_num': 13943,
#                              'course_id': 13203,
#                              'id': 190317,
#                              'school': 'WCAS',
#                              'section': '20',
#                              'subject': 'STAT',
#                              'term': '2019 Fall',
#                              'title': 'Statistical Theory & Methods 1'},
#                             {'catalog_num': '325-0',
#                              'class_num': 13918,
#                              'course_id': 3393,
#                              'id': 190319,
#                              'school': 'WCAS',
#                              'section': '20',
#                              'subject': 'STAT',
#                              'term': '2019 Fall',
#                              'title': 'Survey Sampling'},
#                             {'catalog_num': '330-1',
#                              'class_num': 13919,
#                              'course_id': 3394,
#                              'id': 190320,
#                              'school': 'WCAS',
#                              'section': '1',
#                              'subject': 'STAT',
#                              'term': '2019 Fall',
#                              'title': 'Applied Statistics for Research 1'},
#                             {'catalog_num': '344-0',
#                              'class_num': 13946,
#                              'course_id': 18956,
#                              'id': 190321,
#                              'school': 'WCAS',
#                              'section': '1',
#                              'subject': 'STAT',
#                              'term': '2019 Fall',
#                              'title': 'Statistical Computing'},
#                             {'catalog_num': '370-0',
#                              'class_num': 13947,
#                              'course_id': 20288,
#                              'id': 190322,
#                              'school': 'WCAS',
#                              'section': '20',
#                              'subject': 'STAT',
#                              'term': '2019 Fall',
#                              'title': 'Human Rights Statistics'},
#                             {'catalog_num': '420-1',
#                              'class_num': 13930,
#                              'course_id': 3403,
#                              'id': 190323,
#                              'school': 'WCAS',
#                              'section': '20',
#                              'subject': 'STAT',
#                              'term': '2019 Fall',
#                              'title': 'Introduction to Statistical Theory & '
#                                       'Methodology-1'},
#                             {'catalog_num': '425-0',
#                              'class_num': 13949,
#                              'course_id': 23218,
#                              'id': 190324,
#                              'school': 'WCAS',
#                              'section': '1',
#                              'subject': 'STAT',
#                              'term': '2019 Fall',
#                              'title': 'Sampling Theory and Applications'},
#                             {'catalog_num': '455-0',
#                              'class_num': 14009,
#                              'course_id': 3409,
#                              'id': 190325,
#                              'school': 'WCAS',
#                              'section': '1',
#                              'subject': 'STAT',
#                              'term': '2019 Fall',
#                              'title': 'Advanced Qualitative Data Analysis'},
#                             {'catalog_num': '457-0',
#                              'class_num': 13945,
#                              'course_id': 15783,
#                              'id': 190326,
#                              'school': 'WCAS',
#                              'section': '1',
#                              'subject': 'STAT',
#                              'term': '2019 Fall',
#                              'title': 'Applied Bayesian Inference'}],
#                 'name': 'Statistics',
#                 'symbol': 'STAT'},
#                {'courses': [{'catalog_num': '111-1',
#                              'class_num': 11793,
#                              'course_id': 2343,
#                              'id': 190328,
#                              'school': 'WCAS',
#                              'section': '21',
#                              'subject': 'SWAHILI',
#                              'term': '2019 Fall',
#                              'title': 'Swahili I'},
#                             {'catalog_num': '111-1',
#                              'class_num': 11792,
#                              'course_id': 2343,
#                              'id': 190327,
#                              'school': 'WCAS',
#                              'section': '20',
#                              'subject': 'SWAHILI',
#                              'term': '2019 Fall',
#                              'title': 'Swahili I'},
#                             {'catalog_num': '121-1',
#                              'class_num': 11794,
#                              'course_id': 2346,
#                              'id': 190329,
#                              'school': 'WCAS',
#                              'section': '20',
#                              'subject': 'SWAHILI',
#                              'term': '2019 Fall',
#                              'title': 'Swahili II'}],
#                 'name': 'Swahili',
#                 'symbol': 'SWAHILI'},
#                {'courses': [{'catalog_num': '111-1',
#                              'class_num': 13110,
#                              'course_id': 15936,
#                              'id': 190330,
#                              'school': 'WCAS',
#                              'section': '20',
#                              'subject': 'TURKISH',
#                              'term': '2019 Fall',
#                              'title': 'Turkish I'},
#                             {'catalog_num': '121-1',
#                              'class_num': 13111,
#                              'course_id': 16185,
#                              'id': 190331,
#                              'school': 'WCAS',
#                              'section': '20',
#                              'subject': 'TURKISH',
#                              'term': '2019 Fall',
#                              'title': 'Turkish II'}],
#                 'name': 'Turkish',
#                 'symbol': 'TURKISH'}],
#   'symbol': 'WCAS'}]

# %%
with open('Fall2019_PrunedCoursesData.txt', 'w') as outfile:  
    json.dump(detailedschoolarray, outfile)
